# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
import re
import numpy as np
from nltk.corpus import wordnet
from collections import Counter 
import string

# %% [markdown]
# ### Reading and Preprocessing the Datasets

# %%
raw = pd.read_csv('Raw_Skills_Dataset.csv')
tech = pd.read_csv('Example_Technical_Skills.csv')

# %%
raw.head()
# Out:
#           RAW DATA
# 0         What ifs
# 1        seniority
# 2      familiarity
# 3  functionalities
# 4          Lambdas

# %%
raw.describe()
# Out:
#        RAW DATA
# count     34116
# unique    15677
# top      Python
# freq        272

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34116 entries, 0 to 34115
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   RAW DATA  34116 non-null  object
# dtypes: object(1)
# memory usage: 266.7+ KB

# %%
tech.head()
# Out:
#                 Technology Skills
# 0  !Trak-it Solutions !Trak-it HR
# 1                            .com
# 2                       .htaccess
# 3                            .NET
# 4                        .NET CLR

# %%
tech.describe()
# Out:
#               Technology Skills
# count                     27063
# unique                    27063
# top     High Potential Programs
# freq                          1

# %%
tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27063 entries, 0 to 27062
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Technology Skills  27063 non-null  object
# dtypes: object(1)
# memory usage: 211.6+ KB

# %% [markdown]
# #### Dropping duplicate values

# %%
raw.drop_duplicates(inplace=True)
tech.drop_duplicates(inplace=True)

# %%
raw.describe()
# Out:
#                  RAW DATA
# count               15677
# unique              15677
# top     Ansible/Terraform
# freq                    1

# %%
tech.describe()
# Out:
#               Technology Skills
# count                     27063
# unique                    27063
# top     High Potential Programs
# freq                          1

# %%
raw_list = raw.values.tolist()
print(len(raw_list))
raw_list = np.reshape(raw_list,15677 )
print(raw_list)
# Out:
# 15677
# ['What ifs' 'seniority' 'familiarity' ... 'all applicants'
#  'Self-motivated, enthusiastic and strong drive' 'negotiation']

# %%
tech_list = tech.values.tolist()
print(len(tech_list))
tech_list = np.reshape(tech_list,27063 )
print(tech_list)
# Out:
# 27063
# ['!Trak-it Solutions !Trak-it HR' '.com' '.htaccess' ... 'Zynx'
#  'ZYTO LSA Pro' 'Zyxel']

# %% [markdown]
# ### Converting skills(strings) to lowercase and removing punctuations

# %%
raw_texts = [[word.lower() for word in text.split()] for text in raw_list]
tech_texts = [[word.lower() for word in text.split()] for text in tech_list]

# %%
raw_texts = [''.join(c for c in s if c not in string.punctuation) for s in raw_texts]    
tech_texts = [''.join(c for c in s if c not in string.punctuation) for s in tech_texts]

# %%
raw_texts
# Out:
# ['whatifs',
#  'seniority',
#  'familiarity',
#  'functionalities',
#  'lambdas',
#  'javastreams',
#  'objectorientedanalysis',
#  'relationaldatabases',
#  'sql',
#  'orm',
#  'jpa2',
#  'hibernate',
#  'mybatis',
#  'codeversioningtools',
#  'git..familiarity',
#  'maven',
#  'gradle..familiarity',
#  'continuousintegration',
#  'continuousdeliverydevelopmentprocesses',
#  'jenkins',
#  'bamboo',
#  'familiarity',
#  'frameworks',
#  'transformations',
#  'analyticalreporting',
#  'conceptualdatamodels',
#  'standardnamingconventions',
#  'codingpractices',
#  'consistency',
#  'optimizedsolutions',
#  'methodologies',
#  'highthroughputdataaccessservices',
#  'analyze/profiledata',
#  'conceptual,logicalphysicaldatamodeldesigns',
#  'reportingandanalyticssolutions',
#  'physicaldatabases',
#  'variances',
#  'discrepancies',
#  'allphases',
#  'integrations',
#  'demonstrableexperience',
#  'logicalandphysicaldatamodels',
#  'interpersonalskills',
#  'modernenterprisedataarchitectures',
#  'datatoolsets',
#  'e.g.:datawarehouse',
#  'datamarts',
#  'modelingtools',
#  'profilingtools',
#  'bachelorormasterdegree',
#  'stemmajors',
#  'strongalgorithms',
#  'codingbackground',
#  'eitherjava',
#  'python',
#  'scalaprogrammingexperience',
#  'exceptionalproficiency',
#  'eachfollowingdistributedtechnologies',
#  'relationalstores',
#  'i.e.postgres',
#  'mysql',
#  'oracle',
#  'nosqlstores',
#  '(i.e.bigquery',
#  'clickhouse',
#  'distributedprocessingengines',
#  'i.e.apachespark',
#  'apacheflink',
#  'celery',
#  'distributedqueues',
#  'i.e.apachekafka',
#  'awskinesis',
#  'gcppussub',
#  'standardmethodologies',
#  'gcp',
#  'azure',
#  'aws',
#  'similarcloudplatformtechnologies',
#  'persuasion',
#  'experiencebuildingcloudenvironments',
#  'excellentunix/linuxexperienceandprogrammingexperience',
#  'scripting',
#  'python,shell',
#  'ipcmechanisms',
#  'tcp/ip',
#  'kafka',
#  'zmq',
#  'grpc',
#  'microservicearchitecture',
#  'orchestration',
#  'docker',
#  'kubernetes',
#  'cloudenvironments',
#  'etcd',
#  'servicemeshes',
#  'envoy',
#  'vault',
#  'apigateways',
#  'loadbalancers',
#  'databases',
#  'sql/nosql',
#  'columnardatabases',
#  'distributedconsensus',
#  'captheorem',
#  'raft',
#  'map-reduce,reliablemulticast',
#  'paxos',
#  'ci/cd',
#  'github',
#  'makefiles',
#  'microservices',
#  'gcpnode.js',
#  'restapisservicesexperiencewritingtools',
#  'ruby',
#  'perlexperience',
#  'bazel',
#  'toolingscalaprogrammingexperienceknowledge',
#  'http2/websocket',
#  'binaryprotocolsexperience',
#  'redis',
#  'webuiexperience',
#  'javascript',
#  'html',
#  'css',
#  'algorithms',
#  'standard(w3c)webuiapis',
#  'thefollowingtypesframeworks/libraries/languages',
#  'angular',
#  'meteor',
#  'ember',
#  'knockout',
#  'uicomponentlibraries',
#  'vue',
#  'bootstrap',
#  'es6',
#  'typescript',
#  'dependencyinjectionpatterns',
#  'asyncmoduledefinition',
#  'amd,requirejs',
#  'commonjs',
#  'stylesheetlanguages',
#  'sass',
#  'redux',
#  'reactiveprogramming',
#  'rxjs',
#  'javastrongprogrammingskills',
#  'lambdas',
#  'optionals',
#  'guiceknowledge',
#  'protobufknowledge',
#  ':familiarity',
#  'consumingserviceorientedarchitecturelayers',
#  'apis',
#  'highlyscalableapplications',
#  'webui:deepunderstanding',
#  'json',
#  'javascriptdesign',
#  'architecturalpatterns',
#  'proficiency',
#  'eclipse/netbeans/intellij',
#  'spring/guice',
#  'jpa/hibernate',
#  'javaexperience',
#  'highlydistributedandscalablesystems',
#  'containersknowledge',
#  'multi-threadedconcepts',
#  'latency',
#  'heap',
#  'profiling',
#  'distributedtroubleshooting',
#  'nosql',
#  'mongodb',
#  'cassandra',
#  'javaapplicationservers',
#  'oracleweblogic',
#  'jboss',
#  'tomcat',
#  'jasmine',
#  'karma',
#  'protractor',
#  'junit',
#  'cross-browsertechniques',
#  'chromedevtools',
#  'responsivedesignimplementation',
#  'browserperformanceauditing',
#  'tuning',
#  'distributedcoderepositories',
#  '(git,perforce',
#  'scrumkanban',
#  'guice',
#  'grpc',
#  '',
#  '/btech/bs',
#  'excellentanalyticalandproblem-solvingskills',
#  'proven-deep-expertise',
#  'pythonprogramming',
#  'django',
#  'flask',
#  'anyrdbmsandstrongsqlknowledge',
#  'unixlinuxcommandline',
#  'object-orientedconcepts',
#  'uiframeworks',
#  'usabilitydesign',
#  'hadoophivepresto',
#  'ml/aiframeworks',
#  'tensorflow',
#  'h20',
#  'nosqldatabases',
#  'dockerandcontainerplatforms',
#  'mesos',
#  'kubernetes',
#  'applicationbenchmarking',
#  'optimization',
#  'buildinguserinterfaceapplications',
#  'analyticaldevices',
#  'measurementandcontrolalgorithms',
#  'uiapplications',
#  'analytical,medical,orautomotivedevices',
#  'programminguserinterfaces',
#  'theqtframework',
#  'qml',
#  'qt/c++',
#  'regulatedmarkets',
#  'embeddedlinux-systems',
#  'raspi',
#  'beaglebone',
#  'ip-basednetworkprotocols',
#  'thelinux-yoctodistribution',
#  'myntra’snewproductplatforms',
#  'mentor',
#  'architects',
#  'devopsengineers',
#  'architecturalanddesignbestpractices',
#  'deployment',
#  'scaling',
#  'availabilitycharacteristics',
#  'thelong-termarchitecturaldirection',
#  'platforms/reusablecomponents',
#  'animbledeliveryprocess',
#  'reliability',
#  'extensibility',
#  'deliverables',
#  'nextgenerationextensibleweb',
#  'mobileandfashioncommerceplatforms',
#  'securityprotocols',
#  'customisation',
#  'continuousscaling',
#  'internationalization',
#  'extensions',
#  'thearchitecturalgovernance',
#  'directionalpaths',
#  'newtechnologystacks',
#  'multipletechnologydomains',
#  'myntra',
#  'externaltechnicalforums',
#  'businessstakeholders',
#  'term,long-termroadmaps',
#  'excellentabstraction',
#  'coding',
#  'astartup/e-commerceecosystem',
#  'ahighgrowthmatrixenvironment',
#  'anefficientproficientproblem-solver',
#  'businessandtechnicalperspectives',
#  'workablesolutions',
#  'leadingproductdevelopmentend-end(portfolio',
#  'architectures',
#  'multi-millionsessions/transactions',
#  'rdbmsnosqlstores',
#  'massivelylargescaledistributedinternetsystems',
#  'java/go',
#  'multi-threadingandperformanceorientedprogramming',
#  'highlyscalableproducts',
#  'queues',
#  'object-orientedprogramming',
#  'concurrency',
#  'fundamentals',
#  'developinguser-facingwebapplications',
#  'reusable,modularcode',
#  'bachelor',
#  'backendservices',
#  'reactjs',
#  'js/typescript',
#  'webpackbundling',
#  'devtools',
#  'markuplanguages',
#  'html5',
#  'css3',
#  'pre-processingplatforms',
#  'scss',
#  'mysql',
#  'postgres',
#  'datamodelingskills',
#  'thetestingframeworks',
#  'codeversioningtoolgit',
#  'astandardizeditmethodology',
#  'detaildesignphases',
#  'outputs',
#  'architecturaldevelopment',
#  'modifications',
#  'specifications',
#  'congruence',
#  'thecompatibility',
#  'interdependenttechnologies',
#  'computingrelatedtechnologyprograms',
#  'minimum1yearjavadesignanddevelopmentexperience',
#  'springandhibernatebasedsolutions',
#  'technicalexpertise',
#  'statisticalprogrammingtasks',
#  'thestatisticalprogrammingdepartment',
#  'high-qualitydeliverables',
#  'morecomplexassignedtasks',
#  'appropriatevalidationrequirements',
#  'sops',
#  'checksprogramminglogs',
#  'cleanliness',
#  'inputs',
#  'programmingspecificationsdatasets',
#  'datasets',
#  'handles',
#  'datasetderivations',
#  'programstlfs',
#  'biostatisticaltools',
#  'questionsspecification',
#  'leadprogrammer',
#  'thebiostatisticalteamlead',
#  'supervisor',
#  'projectspecificmacros',
#  'timelyprogressupdates',
#  'eac',
#  'documentstimelines',
#  'biosetup',
#  'integrateddatabases',
#  'projectmacros',
#  'sap',
#  'shells',
#  'programmingspecifications',
#  'safetyoutputs',
#  'sharesaccountability',
#  'contractandbudgetassumptions',
#  'rework',
#  'mentorsjuniorstaff',
#  '(qc)review',
#  'definexmls',
#  'adamreviewersguide',
#  'sdrg',
#  'adrg',
#  'leadprogrammerrole',
#  'proactiveapproach',
#  'efficiencies',
#  'protocols',
#  'rfps',
#  'biddefenses',
#  'operationaltopics',
#  "master'sdegreecomputerscience",
#  "bachelor'sdegreecomputerscience",
#  'cdisc/adam/sdtm',
#  'basesas',
#  'sas/stat',
#  'sasmacrolanguage',
#  'goodorganizational,interpersonal,leadershipandcommunicationskills',
#  'coworkers',
#  'atalented,enthusiastic,anddetail-orienteddataengineer',
#  'anagileway',
#  'analysisdatamodeling',
#  'bigdatapipelines',
#  'thedataanalyticsteam',
#  'coda',
#  'datapipelines',
#  'analyticaltechniques',
#  'insights',
#  'etl',
#  'awstechnologies',
#  'redshift',
#  's3',
#  'emr',
#  'ec2',
#  'dynamodb',
#  'kinesisfirehose',
#  'lambda',
#  'mlteams',
#  'newbehaviouralevents',
#  'pipelines',
#  'ourofflineanalyticscapabilities',
#  'tableau',
#  'ourrealtimedashboardingcapabilities',
#  'bachelor’sdegree',
#  'asimilarquantitativefield',
#  'anothercolumnarstoredw',
#  'cloudsolutionsawsazuregooglecloud',
#  'datavisualization',
#  'hadoop/mapreduce/aws',
#  'spark/scala/pyspark/apachekafkakinesisstreamsawsglue',
#  'reporting/analyticsplatforms',
#  'experiencebuildingflexibledataapis',
#  'thebusinesspreferredqualifications',
#  'adata/softwaredeveloper/scientist',
#  'predictiveanalytics/decisionmodels',
#  'datamininglibraries',
#  'algorithmdesign',
#  'problemsolving',
#  'agiledevelopment',
#  'collaborativefiltering',
#  'ouriosmobileapplication',
#  'highvisibility',
#  'thefundamentals',
#  'relevantsweexperience',
#  'iosapps',
#  'preferably,apps',
#  'theappstore',
#  'xcode..experience',
#  '(mvvm',
#  'multi-threadingandperformancememoryoptimization',
#  'restfulapis',
#  'proficientunderstanding',
#  'git',
#  'individualprojectspriorities',
#  'deadlines',
#  'yourtechnicalexpertise',
#  'bottlenecks',
#  'oursoftwarestack',
#  'rubriksoftwareengineers',
#  'self-starters',
#  'alimitlessdrive',
#  'master’sdegree',
#  'scala',
#  'googlecloudplatform/aws/azure',
#  'unix/linuxenvironments',
#  'windowsenvironments',
#  'networking',
#  'hypervisors',
#  'granularfilerecovery',
#  'kubernetesservice',
#  'elasticcompute',
#  'technicalspecifications',
#  'aconciseandeffectivemanner',
#  'agileactivities',
#  'sprintplanning',
#  'thoroughknowledge',
#  'keyarchitecturaldecisions',
#  'designconsiderations',
#  'detailedrca',
#  'master’sdegree',
#  'object-orientedlanguages',
#  'developingmicroservices',
#  'restfulservices',
#  'othersoadevelopmentexperience',
#  'preferablyaws',
#  'entityframework',
#  'nhibernate',
#  'strongtddapproach',
#  'nunit',
#  'xunit',
#  'oopandsoliddesignprinciples',
#  'publiccloudproviders',
#  'modernjavascriptframeworks',
#  'highlyefficientdatapersistentdesigntechniques',
#  'dataretrievalperformance',
#  '(queries',
#  'designs/queries',
#  'proficientexperience',
#  'relationaldatabases',
#  'microsoftsqlserver/postgres',
#  'othernon-relationaldbs',
#  'parallelworkstreams',
#  'agilepractices',
#  'debugging/troubleshootingfunctionalandtechnicalissues',
#  'performance/optimizationtechniques',
#  'proactivelycodes',
#  'excellentanalytical,quantitative,andproblem-solvingabilities',
#  'minimaloversight',
#  'multipleconcurrentpriorities',
#  'afast-pacedenvironment',
#  'stronginterpersonal',
#  'utilizesknowledge',
#  'xamarin',
#  'transformsbusinessrequirements',
#  'adevopsmodel',
#  'debug',
#  'generatingtestingandtestcases',
#  'uniformity',
#  'variousprototypes',
#  'bachelor’sdegree',
#  'linq',
#  'restapis',
#  'xamarinforms',
#  'xamarinnativedevelopment',
#  '(xamarinios,xamarindroid',
#  'xamarinstudio',
#  'bothappleiosandandroidplatforms',
#  'xamarinapps',
#  'uwp',
#  'xaml',
#  'e.g.azureintegrations',
#  'azureactivedirectory',
#  'notifications',
#  'hockeyapp/visualstudioappcenter',
#  'continuousintegration',
#  'ci',
#  'devops',
#  'automationtesting',
#  'xamarinprofiler',
#  'variouscoderepositories',
#  'tfs',
#  'mvvmarchitecture',
#  'anagilemethodology',
#  'vsts',
#  'overallcrossplatformappdevelopmentecosystem',
#  'lifecycle',
#  'roadmaps',
#  'portableclasslibrary',
#  'pcl',
#  'sqlite',
#  'cross-platformuxdesign',
#  'xamarinbinding',
#  'saphanarestapiintegration',
#  'corejava',
#  'swiftxcode',
#  'afast-pacedcomplexenvironment',
#  'aself-motivatedworkethic',
#  'urgency',
#  'willingness',
#  'allrelevantsops',
#  'servicesintegratehighspot',
#  'externalapis',
#  'crm',
#  'cms',
#  'clean,reusable,supportable,andwell-testedrestfulapis',
#  'highspot’sexternalapi',
#  'highspot’ssalesforceintegrations',
#  'functionality',
#  'ux',
#  'maintainableandtestablecode',
#  'internalandexternaltechnicaldocumentation',
#  'dataformats',
#  'datatransformations',
#  'scalableinternetsoftware',
#  'object-orientedandfunctionaldesignpatterns',
#  'highspot’sinfrastructureplatformcrew',
#  'otherfeaturecrews',
#  'highspot',
#  'highly-scalableandreliableinfrastructure',
#  'otherengineeringcrews',
#  'highly-availabilitydistributedservices',
#  'observability',
#  'sharedframeworks',
#  'caches',
#  'indexes',
#  'highspot’sfeatureengineeringcrews',
#  'aswellaswithdevops/site-reliability',
#  'cloudcomputing',
#  'containerization',
#  'clojure',
#  '..apis',
#  'emergingframeworks',
#  'architecturalpatterns',
#  'node',
#  'typescript',
#  'industryleadingcloudproviders',
#  'operationalefficiencies',
#  'modernecosystems',
#  'automatedbuildanddeploymentpipelines',
#  'collaborativebuildpractices',
#  'acollaborativeproductengineeringteam',
#  'avelocitymultiplier',
#  'therefinement',
#  'theentiresoftwarestack',
#  'api',
#  'uicomponents',
#  'thenorms',
#  'othersoftwaredevelopmentcapabilities',
#  'agiletechniques',
#  'oversight',
#  'theprojectroadmap',
#  'emergingtechnologies',
#  'cloud-basedecosystems',
#  'provenvalidationtechniques',
#  'scripts',
#  'routines',
#  'productionenvironments',
#  'othertalentedsoftwareengineers',
#  'architects',
#  'automatedanalysis',
#  'ui',
#  'dataannotation',
#  'robustcode',
#  'abiotechnology',
#  'automatedanalysis',
#  'annotation',
#  'advanceddisplayanddatamanipulation',
#  'strongpythoncodingskills',
#  'agreatbackcatalogue',
#  'homebrewprojects',
#  'documentation',
#  'yoursleeves',
#  'degreequalification',
#  'ideallysomeexposure',
#  'genomicfileformats',
#  'productenhancements',
#  'workplacesearch',
#  'elasticsearch',
#  'kibana',
#  'internationalteammates',
#  'amostlytext-based,asynchronous,remote-firstteamenvironment',
#  'yearlyconferences',
#  'constructivefeedback',
#  'theteam’soveralltechnicalstrategy',
#  'aproductroadmap',
#  'technicaldeliverables',
#  'animportantandcommunicativepart',
#  'anengagedandspiritedteam',
#  'allsupportandescalationstickets',
#  'workarounds',
#  'promptlyfollow-up',
#  'devops',
#  'self-starter',
#  'ahigh-pressure,fast-paced,fastgrowthenvironment',
#  'knowledgebaseentries',
#  'thesupportportal',
#  'sla',
#  'atimelymanner',
#  'strongtcp/ipknowledge',
#  'proxies',
#  'ngfirewalls',
#  'ssl/ipsec',
#  'vpn',
#  'sso',
#  'dlpandencryptiongateways',
#  'configuration',
#  'unix/linux',
#  'windows\xadbasedsystems',
#  'prioractivedirectory/ldapexperience',
#  'variousscenarios',
#  'tcpdump',
#  '(tcp/ip',
#  'dns',
#  'dhcp',
#  'strongempathy',
#  'interpersonalskills',
#  'zendesk',
#  'othersupportportaltools',
#  'bachelorsormastersdegree',
#  'billions',
#  'excellentgrasp',
#  'advancedsql',
#  'mlopsprocesses',
#  'tooling',
#  'productionanddebuggingcomplexsystems',
#  'theirmathematicalconcepts',
#  'sklearn',
#  'sparkml',
#  'pandas',
#  'numpy',
#  'similarpackages',
#  'deeplearningpackages',
#  'tensorflow',
#  'pytorch',
#  'keras',
#  'spark',
#  'automationtechnologies',
#  'e.g.,kubernetes',
#  'jenkins',
#  'gnn',
#  'rl',
#  'recommendersystems',
#  'nlptechniques',
#  'embeddings',
#  'attentionmechanisms',
#  'theinformation/cybersecuritydomain',
#  'theunderlyingmathematicalmodels',
#  'exploratorydataanalysis',
#  'syntheticdatasets',
#  'statisticalandmachinelearningmodels',
#  'efficacy',
#  'analyzes',
#  'debugs',
#  'softwareenhancements',
#  'local,networked,orinternet-relatedcomputerprograms',
#  'debugging',
#  'necessarymodifications',
#  'reviewsproduct/projectdeliverables',
#  'thelifecyclemethodologies',
#  'i.e.,impactassessments',
#  'externalinternalspecifications',
#  'manuals',
#  'qatestplans',
#  'theacicode',
#  'troubleshooting',
#  '6to8yearsprofessionaljavadevelopmentexperience',
#  'sdlc',
#  'agile',
#  'thefollowingdevelopmentlanguagesframeworkstools',
#  'micro-servicesarchitecture',
#  'containers',
#  'orchestrationtools',
#  'e.g.azure',
#  'openshift',
#  'k8cluster',
#  'micro-servicesdeployment',
#  'otherframeworks/tools',
#  'nginx/ingres',
#  'apigateway',
#  'servicemesh',
#  '(e.g.istio',
#  'sensitivedataencryption',
#  'e.g.hashicorp/hsmintegration',
#  'thefollowingcodeversioning',
#  'i.e.git',
#  'tortoisegitsourcetree',
#  'bitbucket',
#  'jira',
#  'testingframeworks',
#  'i.e.junit',
#  'mockito',
#  'applicationservers',
#  'websphere',
#  'databaseservers',
#  'postgresql',
#  'mssql',
#  'linux',
#  'objectorientedprogrammingknowledge',
#  'shellscripting',
#  'jaxb',
#  'apachecommons',
#  'apachepoi',
#  'eclipsests',
#  'xml',
#  'xsd',
#  'apacheant',
#  'linuxbashscripting',
#  'ddl',
#  'dml',
#  'jdbc',
#  'liquibase',
#  'javamessageservice',
#  'jms',
#  'ourpreferredtechnologystack',
#  '(primarilyelixir/phoenix',
#  'liveview',
#  'rails',
#  'modernjavascript',
#  'amazinggraphql',
#  'ourbackendserviceteams',
#  'modernjavascripttechnologies',
#  'acollaborativeagile/scrumenvironment',
#  'strongcompetencies',
#  'softwarecraftsmanship',
#  'apidevelopment',
#  'sinatra',
#  'github',
#  'astronggrasp',
#  'exq',
#  'sidekiq',
#  'beanstalk',
#  'rabbitmq',
#  'exunit',
#  'rspec',
#  'jest',
#  'pytest',
#  'cachingstrategies',
#  'thirdpartyapis',
#  'elixir',
#  'graphqlapis',
#  'absinthe',
#  'graphql',
#  'subscriptions',
#  'javascriptssr',
#  'startups',
#  'esports',
#  'willingness',
#  'mysql',
#  '(primarilyelixir/phoenix/liveview',
#  'newanalyticsproducts',
#  'ourexistingjava',
#  'deployment',
#  'backendsystems',
#  'restfulwebservices',
#  'e.g.postgres',
#  'columnarand/ortime-seriesdatabases',
#  'e.g.clickhouse,druid',
#  'influxdb',
#  'prometheus',
#  'acohesiveteam',
#  'verbally,documentation',
#  'programmingtasks',
#  'mastery',
#  'reusabledesignpatterns',
#  'strongjavascriptskills',
#  'reactjs',
#  'uichanges',
#  'designspecifications',
#  'coordination',
#  'uiteam',
#  'completefront-endstack',
#  'html/css/sass',
#  'front-endui',
#  'backendservices',
#  'responsivewebpages',
#  "bachelor'sdegree",
#  'bothcustomweb/mobileapplicationdevelopmentcommercialsoftwaresystemsimplementations',
#  'multipletechnicaldisciplines',
#  'qa',
#  'devops',
#  'amodernhighlyresponsiveweb-baseduserinterface',
#  'modularcss',
#  'familiarity',
#  'restapis',
#  'deepintegrations',
#  'automatedtestingsuites',
#  'mocha',
#  'uxteams',
#  'amazingandintuitiveexperiences',
#  'citools',
#  'dev-opsdeploymentprocess',
#  'bdd/tdd',
#  'mentorjuniorengineers',
#  'thefluxdesignpattern',
#  'bddexperience',
#  'restfulapi',
#  'gamereliabilityissues',
#  'front-linedev',
#  'afinalgatekeeper',
#  'hotfixes',
#  'serviceoutages',
#  'e.g.gcp',
#  'e.g.javascript',
#  'scripting',
#  'e.g.bash',
#  'grafana',
#  'newrelic',
#  'stackdriver',
#  'sumologic',
#  'cloudwatch',
#  'distributeddatabasesystems',
#  'bs/ms',
#  'docker',
#  'arestfulapisystem',
#  'e.g.git',
#  'perforce',
#  'performanceprofiling',
#  'node.js',
#  'stakeholders',
#  'highlycomplexuserinterfaces',
#  'androidjava',
#  'androidkotlin',
#  'specializedsoftwareengineeringexperience',
#  'buck/bazel',
#  'well-designed,testable,efficient,securecode',
#  'diversescope',
#  'identifiablefactors',
#  'precedent',
#  'mentornewandjuniorteammembers',
#  'golang',
#  'anequivalentadvancedobject-orientedlanguage',
#  'excellentcommunicationandinterpersonalskills',
#  'backenddevelopmentexperience',
#  'scalable,highavailabilityservices',
#  'buildinglowlatency',
#  'scalableplatform',
#  'rest/graphql',
#  'application-appropriatepersistencesystems',
#  'sql/nosqldatabases',
#  'robustness',
#  'scalability',
#  'automation',
#  'buildanddeploymentprocesses',
#  'timelyresolution',
#  'infrastructureincidents',
#  '(aws/azure/gcp',
#  'micronaut',
#  'quarkus',
#  'low-latencysystems',
#  'nosqldatabases',
#  'eventbrokers',
#  'faas',
#  '(lambdas/gcpfunctions',
#  'bugfixes',
#  'theterraformcommunity',
#  'opensourcecontributors',
#  'plugins',
#  'theterraformecosystem',
#  'theterraformcli',
#  'coreapis',
#  'aseamlessexperience',
#  'terraform’sopensourceandcommercialofferings',
#  'infrastructureautomationtooling',
#  'hashicorpcustomers',
#  'thelargerterraformcommunity',
#  'thefulllifecycle',
#  'mentorship',
#  'large,complexcodebases',
#  'aterraformpractitioner',
#  'thegoprograminglanguage',
#  'curiosity',
#  'ph.d.',
#  'mltechniques',
#  'datadiscretization',
#  'normalization',
#  'sampling',
#  'linearregression',
#  'svms',
#  'deepneuralnetworks',
#  'oneormoredeeplearningsoftwareframeworks',
#  'entrepreneurialandpositiveattitude',
#  'fortune500companies',
#  "bachelor'sdegree",
#  'networking',
#  'anaccrediteduniversity',
#  'https/ssl',
#  'vlans,tcp/ip',
#  'natdevices',
#  'dhcpservers',
#  'firewalls',
#  'writtenandverbalenglishcommunicationskills',
#  'aneverevolvingworkplace',
#  'genuineexcitement',
#  'iot',
#  'industrycertifications',
#  'aplus:aws',
#  'ccna',
#  'ccda',
#  'ccnp',
#  'mcse',
#  'ceh',
#  'microsoftazure',
#  'cissp',
#  'csp',
#  'othercodinglanguages',
#  'linuxsystems',
#  'previousstartupexperience',
#  'informationretrieval',
#  'otherquantitativediscipline',
#  'goodtheoreticalgrounding',
#  'differentoperatingconstraints',
#  'e.g.datadiscretization',
#  'bandits',
#  'reinforcementlearning',
#  'anintuition',
#  'newproblemdomains',
#  'excellentstakeholdercommunication',
#  'oneormoredlsoftwareframeworks',
#  'haves',
#  'e.g.hadoop',
#  'naturallanguageprocessingcontentcontextunderstandingrecommendersystemsgraphgeometricdeeplearningmodel',
#  'learningpredictioninference',
#  'customizations',
#  'evolvingbusinessneeds',
#  'netsuite',
#  'netsuiteerpimplementation',
#  'systemintegrations',
#  'avalara',
#  'paymentprocessors',
#  'bankelectronicfundtransfers',
#  'homegrownsystems',
#  'billing',
#  'scalablesolutions',
#  'enhancementrequests',
#  'thesmoothfunctioning',
#  'validation',
#  'newandexistingconfigurations',
#  'existingsub-optimalfeatures',
#  'completeness',
#  'erp',
#  'automation',
#  'systemoptimizations',
#  'netsuiteerpexperience',
#  'fundamentalsystemintegrationconcepts',
#  'productionintegrations',
#  'anerpand3rdpartysystems',
#  'salesforce.com',
#  'javascript',
#  'unixscriptstoolset',
#  'suitescript',
#  'suiteflows',
#  'webservices/suitetalk',
#  'userprovisioning',
#  'analyticsandschedulingscripts',
#  'multi-entityenvironments',
#  'delays',
#  'ambiguousrequirements',
#  'exceptionalcommunicator',
#  'asaas',
#  'usage/consumption-basedbusiness',
#  'netsuiteadministratorcertification',
#  'bachelorsormastersdegree',
#  'erpimplementationexperience',
#  'customerdelight',
#  'threading/concurrency',
#  'automatedtesting',
#  'otherspecialists',
#  'highthroughputsystems',
#  'largescaleinteractivecommunicationsplatforms',
#  'ourapigateways',
#  'servicescalability',
#  'excellentjavascriptdevelopmentskills',
#  'node.jsecosystem',
#  'messagequeues',
#  'cloudenvironments',
#  'reactwebappdevelopment',
#  'uis',
#  'experiencebuildingapigateways',
#  ...]

# %%
tech_list
# Out:
# array(['!Trak-it Solutions !Trak-it HR', '.com', '.htaccess', ..., 'Zynx',
#        'ZYTO LSA Pro', 'Zyxel'], dtype='<U111')

# %% [markdown]
# ### Skills Extraction using NLTK

# %% [markdown]
# #### Lemmatization

# %%
wnl = WordNetLemmatizer()

# %% [markdown]
# #### We have to get the POS (parts of speech) of a word. For this pupose, we can use Wordnet corpus. It returns all the POS rating of a word in a list

# %%
def get_pos( word ):
    w_synsets = wordnet.synsets(word)

    pos_counts = Counter()
    pos_counts["n"] = len(  [ item for item in w_synsets if item.pos()=="n"]  )
    pos_counts["v"] = len(  [ item for item in w_synsets if item.pos()=="v"]  )
    pos_counts["a"] = len(  [ item for item in w_synsets if item.pos()=="a"]  )
    pos_counts["r"] = len(  [ item for item in w_synsets if item.pos()=="r"]  )
    
    most_common_pos_list = pos_counts.most_common(3)
    return most_common_pos_list[0][0]

# %% [markdown]
# #### Lemmatized the raw skills as well as techical skills

# %%
for word in raw_list:
    print(wnl.lemmatize(word,get_pos(word)))
# Out:
# What ifs
# seniority
# familiarity
# functionality
# Lambdas
# Java Streams
# Object Oriented analysis
# Relational Databases
# SQL
# ORM
# JPA2
# Hibernate
# MyBatis
# code versioning tools
# Git.. Familiarity
# Maven
# Gradle.. Familiarity
# continuous integration
# continuous delivery development processes
# jenkins
# bamboo
# Familiarity
# framework
# transformation
# analytical reporting
# conceptual data models
# standard naming conventions
# coding practices
# consistency
# optimized solutions
# methodology
# high throughput data access services
# analyze/profile data
# conceptual, logical & physical data model designs
# reporting and analytics solutions
# physical databases
# variance
# discrepancy
# all phases
# integration
# Demonstrable experience
# logical and physical data models
# interpersonal skills
# modern enterprise data architectures
# data toolsets
# e.g.: data warehouse
# data marts
# modeling tools
# profiling tools
# Bachelor or Master degree
# STEM majors
# Strong algorithms
# coding background
# either Java
# Python
# Scala programming experience
# Exceptional proficiency
# each following distributed technologies
#  Relational Stores
# i.e. Postgres
# MySQL
# Oracle
# NoSQL Stores
# (i.e. Big Query
# Clickhouse
# Distributed Processing Engines
# i.e. Apache Spark
# Apache Flink
# Celery
# Distributed Queues
# i.e. Apache Kafka
# AWS Kinesis
# GCP PusSub
# standard methodologies
# GCP
# Azure
# AWS
# similar cloud platform technologies
# persuasion
# experience building cloud environments
# Excellent Unix/Linux experience and programming experience
# script
# python, shell
# IPC mechanisms
# TCP/IP
# Kafka
# zmq
# grpc
# microservice architecture
# orchestration
# docker
# kubernetes
# cloud environments
# etcd
# service meshes
# envoy
# vault
# API gateways
# load balancers
# database
# sql/nosql
# columnar databases
# distributed consensus
# CAP Theorem
# RAFT
# map-reduce, reliable multicast
# Paxos
# CI/CD
# Github
# Makefiles
# Microservices
# GCPNode.js
# REST APIs servicesExperience writing tools
# Ruby
# PerlExperience
# Bazel
# toolingScala programming experienceKnowledge
# HTTP 2/websocket
# binary protocolsExperience
# Redis
# Web UIExperience
# JavaScript
# HTML
# CSS
# algorithm
# standard (W3C) Web UI APIs
# the following types frameworks/libraries/languages
# Angular
# Meteor
# Ember
# Knockout
# UI Component libraries
# Vue
# Bootstrap
# ES6
# TypeScript
# Dependency injection patterns
# Async Module Definition
# AMD, requireJS
# commonJS
# Stylesheet languages
# SASS
# Redux
# Reactive Programming
# RxJS
# JavaStrong programming skills
# lambda
# optionals
# Guice knowledge
# Protobuf knowledge
# :Familiarity
# consuming service oriented architecture layers
# APIs
# highly scalable applications
# Web UI:Deep understanding
# JSON
# JavaScript Design
# Architectural Patterns
# Proficiency
# , Eclipse/NetBeans/IntelliJ
# Spring/Guice
# JPA/Hibernate
# JavaExperience
# highly distributed and scalable systems
# Containers knowledge
# Multi-threaded concepts
# latency
# heap
# profile
# distributed troubleshooting
# NoSQL
# MongoDB
# Cassandra
# Java Application Servers
# Oracle WebLogic
# JBoss
# Tomcat
# Jasmine
# Karma
# Protractor
# Junit
# Cross-browser techniques
# Chrome Dev Tools
# Responsive design implementation
# Browser performance auditing
# tune
# distributed code repositories
# (Git, Perforce
# Scrum / Kanban
# Guice
# GRPC
# -
# /BTech/BS
# Excellent analytical and problem-solving skills
# Proven-deep-expertise
# Python programming
# Django
# Flask
# any RDBMS and strong SQL knowledge
# Unix / Linux command line
# Object-oriented concepts
# UI frameworks
# usability design
# Hadoop / Hive / Presto
# ML/AI frameworks
# TensorFlow
# H20
# noSQL databases
# docker and container platforms
# Mesos
# Kubernetes
# Application benchmarking
# optimization
# Building user interface applications
# analytical devices
# measurement and control algorithms
# UI Applications
# analytical, medical, or automotive devices
# programming user interfaces
# the Qt Framework
# QML
# Qt/C++
# regulated markets
# embedded Linux-Systems
# RasPi
# BeagleBone
# IP-based network protocols
# the Linux-Yocto distribution
# Myntra’s new product platforms
# mentor
# Architects
# DevOps engineers
# architectural and design best practices
# deployment
# scale
# availability characteristics
# the long-term architectural direction
# platforms/ reusable components
# a nimble delivery process
# reliability
# extensibility
# deliverable
# next generation extensible web
# mobile and fashion commerce platforms
# security protocols
# customisation
# continuous scaling
# internationalization
# extension
# the architectural governance
# directional paths
# new technology stacks
# multiple technology domains
# Myntra
# external technical forums
# business stakeholders
# term, long-term roadmaps
# excellent abstraction
# cod
# a startup/e-commerce ecosystem
# a high growth & matrix environment
# an efficient proficient problem-solver
# business and technical perspectives
# workable solutions
# leading product development end-end (portfolio
# architecture
# multi-million sessions/transactions
# rdbms & NoSQL stores
# massively large scale distributed internet systems
# Java/GO
# multi-threading and performance oriented programming
# highly scalable products
# queue
# object-oriented programming
# concurrency
# fundamental
# Developing user-facing web applications
# reusable, modular code
# Bachelor
# Backend services
# React JS
# JS/TypeScript
# Webpack bundling
# Dev tools
# markup languages
# HTML5
# CSS3
# pre-processing platforms
# SCSS
# Mysql
# Postgres
# Data modeling skills
# the testing frameworks
# code versioning tool - Git
# a standardized IT methodology
# Detail Design phases
# output
# architectural development
# modification
# specification
# congruence
# the compatibility
# interdependent technologies
# computing related technology programs
# Minimum 1 year Java design and development experience
# Spring and Hibernate based solutions
# technical expertise
# statistical programming tasks
# the Statistical Programming department
# High-Quality Deliverables
# more complex assigned tasks
# appropriate validation requirements
# SOPs
# Checks programming logs
# cleanliness
# Inputs
# programming specifications datasets
# datasets
# Handles
# dataset derivations
# Programs TLFs
# biostatistical tools
# questions specification
# lead programmer
# the Biostatistical Team Lead
# supervisor
# project specific macros
# timely progress updates
# EAC
# documents timelines
# BIOSETUP
# integrated databases
# project macros
# SAP
# shell
# programming specifications
# safety outputs
# Shares accountability
# contract and budget assumptions
# rework
# mentors junior staff
# (QC) review
# define xmls
# ADaM reviewers guide
# SDRG
# ADRG
# lead programmer role
# proactive approach
# efficiency
# protocol
# RFPs
# bid defenses
# operational topics
# Master's Degree Computer science
# Bachelor's Degree Computer science
# CDISC/ADaM/SDTM
# Base SAS
# SAS/STAT
# SAS Macro Language
# Good organizational, interpersonal, leadership and communication skills
# coworkers
# a talented, enthusiastic, and detail-oriented Data Engineer
# an agile way
# analysis data modeling
# big data pipelines
# the Data Analytics team
# Coda
# data pipelines
# analytical techniques
# insight
# ETL
# AWS technologies
# Redshift
# S3
# EMR
# EC2
# DynamoDB
# Kinesis Firehose
# Lambda
# ML teams
# new behavioural events
# pipeline
# our offline analytics capabilities
# Tableau
# our real time dash boarding capabilities
# Bachelor’s degree
# a similar quantitative field
# another columnar store DW
# cloud solutions / AWS / Azure / Google cloud
# data visualization
# Hadoop/MapReduce/AWS
# Spark/Scala/PySpark/ Apache Kafka / Kinesis Streams / AWS Glue
# reporting/analytics platforms
# Experience building flexible data APIs
# the business Preferred Qualifications
# a data/software developer/scientist
# predictive analytics/decision models
# data mining libraries
# algorithm design
# problem solving
# Agile Development
# Collaborative Filtering
# our iOS mobile application
# high visibility
# the fundamentals
# relevant SWE experience
# iOS apps
# Preferably, apps
# the AppStore
# XCode.. Experience
# (MVVM
# Multi-threading and performance & memory optimization
# RESTful APIs
# Proficient understanding
# Git
# individual projects priorities
# deadline
# your technical expertise
# bottleneck
# our software stack
# Rubrik Software Engineers
# self-starter
# a limitless drive
# Master’s degree
# Scala
# Google Cloud Platform/AWS/Azure
# Unix/Linux environments
# Windows environments
# network
# hypervisors
# granular file recovery
# Kubernetes Service
# elastic compute
# technical specifications
# a concise and effective manner
# agile activities
# sprint planning
# thorough knowledge
# key architectural decisions
# design considerations
# detailed RCA
# master’s degree
# object-oriented languages
# developing Microservices
# RESTful services
# other SOA development experience
# preferably AWS
# Entity Framework
# Nhibernate
# Strong TDD approach
# Nunit
# xUnit
# OOP and SOLID design principles
# public cloud providers
# modern java script frameworks
# Highly efficient data persistent design techniques
# data retrieval performance
# (queries
# designs/queries
# Proficient experience
# relational databases
# Microsoft SQL Server/Postgres
# other non-relational DBs
# parallel work streams
# Agile practices
# Debugging/Troubleshooting functional and technical issues
# Performance/Optimization techniques
# proactively codes
# Excellent analytical, quantitative, and problem-solving abilities
# minimal oversight
# multiple concurrent priorities
# a fast-paced environment
# Strong interpersonal
#  Utilizes knowledge
# Xamarin
#  Transforms business requirements
# a DevOps model
# debug
#  Generating testing and test cases
# uniformity
# various prototypes
#  Bachelor’s degree
# LINQ
# Rest APIs
# Xamarin Forms
# Xamarin Native development
# (Xamarin iOS, Xamarin Droid
# Xamarin Studio
# both Apple iOS and Android platforms
# Xamarin Apps
# UWP
# XAML
# e.g. Azure integrations
# Azure Active Directory
# Notifications
# HockeyApp/Visual Studio App Center
# Continuous Integration
# CI
# DevOps
# Automation Testing
# Xamarin Profiler
# Various code repositories
# TFS
# MVVM Architecture
# an Agile methodology
# VSTS
# Overall Cross Platform app development ecosystem
# lifecycle
# roadmaps
# Portable Class Library
# PCL
# SQLite
# cross-platform UX design
# Xamarin Binding
# SAP HANA REST API Integration
# Core Java
# Swift / XCode
# a fast-paced & complex environment
# a self-motivated work ethic
# urgency
#  Willingness
# all relevant SOPs
# servicesIntegrate Highspot
# external APIs
# CRM
# CMS
# clean, reusable, supportable, and well-tested RESTful APIs
# Highspot’s external API
# Highspot’s Salesforce integrations
# functionality
# UX
# maintainable and testable code
# internal and external technical documentation
# data formats
# data transformations
# scalable internet software
# object-oriented and functional design patterns
# Highspot’s Infrastructure Platform crew
# other feature crews
# Highspot
# highly-scalable and reliable infrastructure
# other engineering crews
# highly-availability distributed services
# observability
# shared frameworks
# cache
# index
# Highspot’s feature engineering crews
# as well as with DevOps/Site-Reliability
# cloud computing
# containerization
# Clojure
# .. APIs
# emerging frameworks
# architectural patterns
# Node
# Typescript
# industry leading cloud providers
# Operational efficiencies
# modern ecosystems
# automated build and deployment pipelines
# Collaborative build practices
# a collaborative product engineering team
# a velocity multiplier
# the refinement
# the entire software stack
# API
# UI components
# the norms
# other software development capabilities
# agile techniques
# oversight
# the project roadmap
# emerging technologies
# cloud-based ecosystems
# proven validation techniques
# script
# routine
# production environments
# other talented software engineers
# architect
# Automated analysis
# UI
# Data annotation
# robust code
# a biotechnology
# automated analysis
# annotation
# advanced display and data manipulation
# strong Python coding skills
# a great back catalogue
# homebrew projects
# documentation
# your sleeves
# Degree qualification
# Ideally some exposure
# genomic file formats
# product enhancements
# Workplace Search
# Elasticsearch
# Kibana
# international teammates
# a mostly text-based, asynchronous, remote-first team environment
# yearly conferences
# constructive feedback
# the team’s overall technical strategy
# a product roadmap
# technical deliverables
# an important and communicative part
# an engaged and spirited team
# all support and escalations tickets
# workarounds
# promptly follow-up
# DevOPS
# Self-starter
# a high-pressure, fast-paced, fast growth environment
# knowledge base entries
# the Support Portal
# SLA
# a timely manner
# Strong TCP/IP knowledge
# Proxies
# NG Firewalls
# SSL/IPSec
# VPN
# SSO
# DLP and Encryption gateways
# configuration
# UNIX/Linux
# Windows­ based systems
# prior Active Directory/LDAP experience
# various scenarios
# tcpdump
# (TCP/IP
# DNS
# DHCP
# Strong empathy
# Interpersonal Skills
# Zendesk
# other support portal tools
# Bachelors or Masters degree
# billion
# Excellent grasp
# advanced SQL
# MLOps processes
# tool
# production and debugging complex systems
# their mathematical concepts
# sklearn
# SparkML
# panda
# NumPy
# similar packages
# deep learning packages
# Tensorflow
# PyTorch
# Keras
# Spark
# automation technologies
# e.g., Kubernetes
# Jenkins
# GNN
# RL
# Recommender Systems
# NLP techniques
# embeddings
# attention mechanisms
# the information/cyber security domain
# the underlying mathematical models
# exploratory data analysis
# synthetic data sets
# statistical and machine learning models
# efficacy
# Analyzes
# debug
# software enhancements
# local, networked, or Internet-related computer programs
# debug
# necessary modifications
# reviews product/project deliverables
# the life cycle methodologies
# i.e., impact assessments
# external & internal specifications
# manual
# QA test plans
# the ACI Code
# troubleshoot
# 6 to 8 years professional Java development experience
# SDLC
# Agile
# the following development languages / frameworks / tools
# Micro-services architecture
# container
# orchestration tools
# e.g. Azure
# OpenShift
# K8 cluster
# micro-services deployment
# other frameworks/tools
# Nginx/Ingres
# API Gateway
# Service Mesh
# (e.g. Istio
# sensitive data encryption
# e.g. HashiCorp/HSM integration
# the following code versioning
# i.e. Git
# TortoiseGit / Sourcetree
# BitBucket
# JIRA
# testing frameworks
# i.e. Junit
# Mockito
# Application Servers
# WebSphere
# Database Servers
# PostgreSQL
# MSSQL
# Linux
# Object Oriented Programming knowledge
# shell scripting
# JAXB
# Apache Commons
# Apache POI
# Eclipse / STS
# XML
# XSD
# Apache Ant
# Linux bash scripting
# DDL
# DML
# JDBC
# liquibase
# Java Message Service
# JMS
# our preferred technology stack
# (Primarily Elixir/Phoenix
# LiveView
# Rails
# modern JavaScript
# amazing GraphQL
# our backend service teams
# modern JavaScript technologies
# a collaborative agile/scrum environment
# strong competencies
# software craftsmanship
# API development
# Sinatra
# GitHub
# A strong grasp
# Exq
# Sidekiq
# Beanstalk
# RabbitMQ
# ExUnit
# RSpec
# Jest
# pytest
# caching strategies
# third party APIs
# Elixir
# GraphQL APIs
# Absinthe
# GraphQL
# subscription
# JavaScript SSR
# startup
# esports
# Willingness
# MySql
# (Primarily Elixir/Phoenix/LiveView
# new analytics products
# our existing Java
# Deployment
# backend systems
# RESTful webservices
# e.g. Postgres
# columnar and/or time-series databases
# e.g. ClickHouse, Druid
# InfluxDB
# Prometheus
# a cohesive team
# verbally, documentation
# programming tasks
# mastery
# reusable design patterns
# strong Java script skills
# ReactJS
# UI changes
# design specifications
# coordination
# UI Team
# complete front-end stack
# HTML/CSS/SASS
# front-end UI
# backend services
# responsive web pages
#  Bachelor's degree
# both custom web/mobile application development & commercial software systems implementations
# multiple technical disciplines
# QA
# devops
# a modern highly responsive web-based user interface
# modular CSS
#  Familiarity
# REST APIs
# deep integrations
# automated testing suites
# Mocha
# UX teams
# amazing and intuitive experiences
# CI tools
# Dev-Ops Deployment process
# BDD/TDD
#  Mentor junior engineers
# the Flux Design Pattern
# BDD Experience
# RESTFUL API
# game reliability issues
# front-line dev
# a Final Gatekeeper
# hotfixes
# service outages
# e.g. GCP
# e.g. JavaScript
# Scripting
# e.g. Bash
# Grafana
# NewRelic
# Stackdriver
# Sumo Logic
# CloudWatch
# distributed Database systems
# BS/MS
# Docker
# a RESTful API system
# e.g. Git
# Perforce
# performance profiling
# node.js
# stakeholder
# highly complex user interfaces
# Android java
# Android Kotlin
# specialized software engineering experience
# Buck/Bazel
# well-designed, testable, efficient, secure code
# diverse scope
# identifiable factors
# precedent
#  Mentor new and junior team members
# Golang
# an equivalent advanced object-oriented language
#  Excellent communication and interpersonal skills
#  Backend development experience
# scalable, high availability services
#  Building low latency
# scalable platform
# REST/GraphQL
# application-appropriate persistence systems
# SQL/NoSQL Databases
# robustness
# scalability
#  Automation
# build and deployment processes
# timely resolution
# infrastructure incidents
# (AWS/Azure/GCP
# Micronaut
# Quarkus
# low-latency systems
# NoSQL Databases
# Event Brokers
# FaaS
# (Lambdas/GCP Functions
# bugfixes
# the Terraform community
# open source contributors
# plugins
# the Terraform ecosystem
# the Terraform CLI
# core APIs
# a seamless experience
# Terraform’s open source and commercial offerings
# infrastructure automation tooling
# HashiCorp customers
# the larger Terraform community
# the full lifecycle
# mentorship
# large, complex codebases
# a Terraform practitioner
# the Go programing language
# curiosity
# Ph.D.
# ML techniques
# , data discretization
# normalization
# sampling
# linear regression
# SVMs
# deep neural networks
# one or more deep learning software frameworks
# Entrepreneurial and positive attitude
# Fortune 500 companies
# Bachelor's degree
# Networking
# an accredited university
# HTTPS/SSL
# VLANs, TCP/IP
# NAT devices
# DHCP servers
# Firewalls
# written and verbal English communication skills
# an ever evolving workplace
# Genuine excitement
# IoT
# Industry certifications
# a plus: AWS
# CCNA
# CCDA
# CCNP
# MCSE
# CEH
# Microsoft Azure
# CISSP
# CSP
# other coding languages
# Linux systems
# previous startup experience
# information retrieval
# other quantitative discipline
# Good theoretical grounding
# different operating constraints
# e.g. data discretization
# bandit
# reinforcement learning
# an intuition
# new problem domains
# Excellent stakeholder communication
# one or more DL software frameworks
# have
# e.g. Hadoop
# Natural Language ProcessingContent & Context UnderstandingRecommender SystemsGraph / Geometric Deep LearningModel
# learningPrediction / Inference
# customizations
# evolving business needs
# NetSuite
# Netsuite ERP - Implementation
# system integrations
# Avalara
# payment processors
# bank electronic fund transfers
# homegrown systems
# Billing
# scalable solutions
# enhancement requests
# the smooth functioning
# validation
# new and existing configurations
# existing sub-optimal features
# completeness
# ERP
# automation
# system optimizations
# NetSuite ERP experience
# fundamental system integration concepts
# production integrations
# an ERP and 3rd party systems
# Salesforce.com
# Javascript
# Unix scripts tool set
# SuiteScript
# SuiteFlows
# Web Services/SuiteTalk
# user provisioning
# analytics and scheduling scripts
# multi-entity environments
# delay
# ambiguous requirements
# Exceptional communicator
# a SaaS
# usage/consumption-based business
# NetSuite Administrator Certification
# Bachelors or masters degree
# ERP implementation experience
# customer delight
# threading/concurrency
# automated testing
# other specialists
# high throughput systems
# large scale interactive communications platforms
# our API gateways
# service scalability
# Excellent JavaScript development skills
# Node.js ecosystem
# message queues
# Cloud environments
# React web app development
# UIs
# Experience building API gateways
# CI/CD technology
# workflow
# Real-time 2D/3D applications
# Mentor
# standard methodology solutions
# TPM
# task
# cloud workspace
# pipeline automation/orchestration
# VM/container management
# Proven programming skills
# cloud drive / cloud workspaces
# Node.js
# the latest iOS/Swift trends
# expressive, readable, composable, and testable Swift code
# iOS provisioning profiles
# certificate
# Demonstrable understanding
# the iOS application & view lifecycles
# functional & reactive programming
# Observance
# Clean architectural and coding principles
# Good problem-solving skills
# Excellent verbal communication skills
# constructive criticism
# maturity
# newly-learned knowledge/patterns
# Kotlin Multiplatform.. Experience
# Mobile Automation Testing
# Fastlane
# CI/CD workflows
# live iOS/Cocoa applications
# SwiftUI
# the backend.. Experience
# Bitbucket
# TDD
# the latest Android / Kotlin trends
# expressive, readable, composable, and testable Kotlin code
# Android SDK
# the Android application & view lifecycles
# Good verbal communication skills
# RxJava/RxKotlin
# Jetpack Compose
# cross-functional alignment
# estimation
# simple and elegant designs
# an inclusive environment
# all backgrounds
# Analytics
# a service oriented architecture
# resiliency
# SLI
# SLO
#  Augment instrumentation
# a cohesive dependency mapping
#  Build command and control automations
# TTR
# Toil
# oncall and triage rotation
#  Linux, Networking and AWS experience
# container platforms
# (e.g., Docker
# Kibana/Grafana
# Logstash
# kafka
# automation systems
# saltstack
# Python/Kotlin/Go
# high performance networking
# (Quic
# network layer optimization
# Real Time transaction protocols/methods
# HTTP2
# MQTT
#  Recommends
# snoop
# other network sniffers
# most protocols
# UDP
# our Compute platform
# Operability
# Resilience
# full region failover
# the roadmap
# Affirm’s Compute platform infrastructure
# both organic growth and traffic spikes
# self-service tooling
# rapid provisioning
# other Cloud vendors
# the Kubernetes ecosystem
# their compute infrastructure
# a growth mindset
# our new Observability Infrastructure
#  Migrate infrastructure
# our growing infrastructure AWS
# observability/monitoring systems
#  Linux and AWS experience
# ansible, puppet
# python
# new Affirm products
# ecosystem
# real time stream processing data pipelines
# Affirm's future growth
# strict SLAs
# Affirm
# the reliability
# scalable data processing systems
# MapReduce
# data science and analytics teams
# robust and highly available infrastructure
# scalable and efficient data processing systems
# Relational and NoSQL databases
# Data Warehouse solutions
# the Consul automation tools
# the larger Consul community
# the network topologies
# constraint
# those insights
# new functionality
# substantive changes
# an async process
# example UX
# peer feedback
# service-oriented architectures
# internal tooling
# Empathy
# tradeoff
# the broader service mesh ecosystem
# practitioner
# Curiosity
# Raft and Paxos variants
# novel algorithms
# Build and architect systems
# extremely large-scale global fleets
# the large Consul community
# less experienced teammates
# reusable white label systems
# seamless integration
# live ops
# optimization
# the dev team
# programming deliverables
# TDDs
# other technical documentation
# Bachelor’s Degree
# #
# social or freemium game economies
# a fast-paced team environment
# changing deadlines
# other devs
# F2P games
# F2P success
# minimal iterations
# user friendly APIs
# gameplay logic
# performance bottlenecks
# well-documented code
# modularity
# Obj-C
# computer science fundamentals
# minimal guidance
# Exceptional problem solving
# debugging skills
# B.S.
# Shipped multiple applications
# mobile or console game development
# Experience building frameworks
# our frameworks
# ugui/uitoolkit
# Addressable Assets
# Asset Bundles
# WebSockets
# MZ development
# delivery pipelines
# velocity
# kubernetes production pipelines
# Linux and Mac OSX operating systems
# Android release pipelines
# Subversion
# tool-chains
# continuous integration systems
# preferably Jenkins
# Mac OSX
# Game Development Cycles
# preferably MySQL
# Lua
# PHP
# package and automation tools
# Puppet
# Ansible
# the most impactful features
# external vendors
# good architectural standards
# blockchain backed game creation
# Ship exceptional user experiences
# clear definitions
# accessible, responsive, and performant user experiences
# Pragmatic approach
# web3.js
# proactive involvement
# build pipeline tools
# gulp
# sas
# typescript
# javascript minifiers
# large, long lived backend code bases
# sustainable patterns
# fluency
# Java/JEE
# relevant transferable technologies
# Fluency
# Java Spring
# Vert.x
# service application frameworks
# maven
# gradle
# redis
# dynamodb
# cassandra
# SEO teams
# branded IP titles/games
# Solana
# Ethereum
# Blockchain tech
# modern systems architectures
# its web server frameworks
# e.g. Flask
# a demonstrable understanding
# core HTTP REST implementations
# SQL and NoSQL databases
# data modeling
# Strong written and verbal communication skills
# Apache NiFi.. Golang service best practices
# concurrent designs
# Deployment automation
# scalable infrastructure
# common vulnerabilities
# Webpack
# test environments
# automation infrastructure
#  2+ years software QA experience
# Unix-based operating systems
#  Proficiency
# QA methodologies
# CI/CD processes
# API test automation
# problem solver
# reliable and scalable online services
# robust service orchestration
# high-volume, consumer-facing applications
# VMs
# Linux containers
# matchmaking
# heuristic based optimization problems
# experiment/data driven system enhancement
# adaptability
# the team’s microservices
# Perfecto products
# the everlasting effort
# technical architecture discussions
# Java development experience
# Strong proficiency
# Java backend infrastructure
# NodeJS
# large-scale production databases
# cloud services API
# backend deployment
# AWS platform
# B.Sc
# foundational components
# our backend services
# other backend teams
# evolving software development
# junior and intermediate developers
# Experience designing
# solid technical writing abilities
# gRPC
# RocksDB
# functional programming
# excellent and fluent UI interfaces
# indicator
# functional requirement documents
# guide
# new development initiatives
# Frontend software development
# JS ecosystem
# (NPM/Yarn
# cross-browser compatibility issues
# iterative development
# architectural and design discussions
# a fast paced environment
# SEO principles
# web accessibility development
# UX/user-empathy
# the operational efficiency
# visibility
# design documentation
# outages/incidents
# (ITIL - Problem Management
# the client’s infrastructure
# the occurrence
# repetitive administrative and operational tasks
# team documentation
# schedule
# client environments
# audit activities
# team mates
# an escalation capacity
# microservices architecture
# container technologies
# , Docker
# at least one major cloud provider
# code deployment
# Terraform
# software development lifecycles
# Comprehensive systems hardware
# network troubleshooting experience
# Common Linux distribution platform installation
# performance tuning
# TCP/IP networking
# NIC bonding and network services configuration
# (DNS
# NTP
# SMTP
# at least one hypervisor
# VMware
# Hyper-V
# KVM
# IaaS
# PaaS
# SaaS
# pro
# con
# virtualization
# web servers
# network load balancers
# bash
# ruby
# at least one major configuration management framework
# i.e. Puppet
# Experience managing networking devices
# switch
# firewall
# vendor
# DevOps tools
# NMS
# accurate work scheduling
# estimation
# willingness
# software engineering and design pattern fundamentals
# language specifications
# syntax
# CSS levels
# Next.js
# UI quality tools
# specifically Cypress
# aesthetic
# the UI
# technological trends
# Cloud Service Providers
# AWS / Azure / GCP
# a UI
# Kotlin
# REST API based products
# Strong reasoning
# programming and scripting skills
# Android dev
# JS/AngularJS dev
# agile development
# , CI/CD, sprints, code reviews
# (SQL/NO-SQL databases
# MVVM
# offline data storage
# latest advancements
# CameraX, Dagger2
# TensorFlow lite
# other frameworks
# iOS/hybrid apps
# KMM
# Kotlin Multiplatform Mobile
# VueJS
# your teammates
# reliable, well designed and well-tested systems
# the Java stack
# dynamic JavaScript-based web applications
# the Nexus Repository OSS and Nexus Repository Pro team
# continuous integration and/or delivery pipelines
# Bamboo
# API design principles
# NoSQL databases
# an Agile remote work environment
# sponsorship
# the Sonatype Lift team
# our SaaS code-analysis platform
# reliability issues
# Site Reliability Engineering
# SRE
# Sonatype
# Haskell
#  Experience producing and/or consuming REST API' s.
# linux
# Unix-based OS Experience
# CI/CD technologies
# GitHub Actions
# the Research and Analytics team
# full-stack developers
# short-term prototypes
# our data pipelines
# operational uptime
# exploration
# ex: Java
# , Spark
# Hadoop
# Hive
# non-relational databases
# : HBase
# : AWS
# data warehouses
# a notebook environment
# ex: Databricks
# Jupyter Notebook
# Confluence
#  Analyze
# prototype
# the complete software lifecycle
# a high-performing scrum team
# Dayforce personnel
# a scalable SaaS enterprise application
#  Assess risks
#  Onboard
# Med - Large size/complexity
# tech stack
#  Intellectual curiosity
#  Excellent communication and collaboration skills
# emerging web development models
# scalable applications
# Web Services Protocols
# WCF
# relational database systems
#  Experience building architectural and low-level integration components
# interface
# messaging components
# import/export frameworks
# microservices based architecture
# advanced programming constructs
# multi-threaded programming
# dependency injection
# performance optimizations
# MVC web frameworks
# user interface components
# JavaScript-based web and mobile applications
# the React open-source library ecosystem
# an agile development environment
# SaaS products
# highly scalable and available innovative solutions
# strategic technical directions
#  Mentor
# the Product Roadmap
# development initiatives
# complex SaaS and/or cloud-based applications
#  Technical fluency
#  Strong business acumen
# non-technical stakeholders
# data analytics
# PowerShell
# Azure and cloud-native architecture
# message
# the latest container systems
# CI/CD pipelines
# DevOps practices
#  Excellent collaboration and communication skills
#  Mentor other developers
# object-oriented design
# TSQL and relational database systems
# one or more architectural and low-level components
# build and deployment systems
# log
# one or more advanced programming constructs
# performance optimization
# scrum
# highly-performant and scalable applications
# OAuth
# OpenID Connect protocols
# various authentication solutions
# Multi-factor authentication
# common web application security vulnerabilities
# one or more modern JavaScript libraries
# Dojo
# Backbone
# jQuery
# object-oriented programming principals
# SQL database
# TSQL
#  Good analytical and problem-solving skills
#  Excellent team collaboration and communication skills
# Agile projects
# Azure DevOps Server
# CI build process
# Azure/AWS cloud platforms
# various network protocols
# Android or Linux kernels
# Android OS
#  Update HTML/JavaScript section
# JavaScript frameworks
# Kotlin / Kotlin multiplatform
# C++ programing
#  Native iOS development
# Swift programming expertise
# Apple’s HIG
# other multiplatform frameworks
#  Workforce management domain
# complete software lifecycle
# the required functionality
# a scalable enterprise application
# #NAME?
#  Kotlin and Java programming expertise
#  Good communicator
# a cross functional distributed team
# best coding practices
# high performing UI controls
#  Backend development
# (Services/APIs/Background Jobs
#  Automated Testing Development
# automated testing framework
# Selenium/Gherkin
# Speckflow
# other modern JavaScript frameworks
# a microservice architecture
# mock
# Gherkin
# Cucumber
# Specflow
#  SQL
# RDBMS
#  No-SQL databases exposure
#  Agile - Scrum
# UI design tradeoffs
# a mentor
# large, well maintained codebases
# long-term code maintainability
# a superlative user experience
# an inclusive culture
# statistical tables
# summary
# analysis databases
# derived datasets
# database quality control checks
# programming documentation
# advanced technical expertise
# conjunction
# macro
# supervision
# forecast
# quote assumptions
# intermediate level knowledge
# Master's Degree
# Bachelor's Degree Computer Science
# computing applications
# technical documentation
# query optimization
# memory utilization
# multi -threaded programming
# application tuning
# latest happenings
# complimentary product development capabilities
# discipline
# holistic discussions
# the broader product development lifecycle
# 3Pillar
# intern
# AngularJS
# ASP.NET
# Web API
# nUnit
# Dependency Injection
# Web Api
# Entity Framework/ORM
# Multi-Threading
# Object Oriented Design skills
# database - joins
# stored procedures
# database optimization
# code verification
# static code analysis
# automated build
# metric
# analytic and troubleshooting skills
# debugging and performance profiling
# delegate
# generic
# the Cloud Azure
# Strong written and oral communication skills
# internal stakeholders
# Basis Technologies DSP systems
# system and applications deployments
# software deployments
# problem-solving
# Linux Operating Systems
# e.g., Debian, Ubuntu. CentOS
# infrastructure management and automation systems
# (e.g., Ansible, Chef
# SaltStack
# , MongoDB
# networking protocols
# monitoring/graphing systems
# Bash
# sharding
# cluster
# replication
# our internal product and tooling team
# underlying cloud infrastructure
# complex and varied Cloud Data
# difficult data and analytics use cases
# existing data warehouses
# premise
# one cloud provider
# highly reliable software and data pipelines
# continuous integration/continuous delivery
# automated data security and data governance best practices
# full multi-source data ingestion
# analytic workloads
# better scalability
# complex functional and technical requirements
# reliable and maintainable code
# reusable accelerators
# data flow integrations
# Diagnostics
# configuration reviews
# Athena
# Glue
# Big Query
# Dataproc
# Dataflow
# Google Cloud Platform data technologies
# Google BigQuery
# Google DataFlow
# PySpark
# SparkSQL
# the Dataframe Application Programming Interface
# Spark queries
# robust, automated and reliable data pipelines
# large dataset
# strong SQL skills
# data warehouse technologies
# Conventional RDBMS
# BigQuery
# Microsoft Azure SQL Data Warehouse
# a Data Orchestration solutions
# Airflow
# Oozie
# Luigi
# Talend
# the trade-offs
# automated deployment pipelines
# devops tools
# persistence
# e.g. warehousing
# Pythian
# EGSE
# satellite
# proper repeatability
# detailed analyses
# digital channelize
# board processing design specification
# Payload throughput
# budget
# multi-beam systems
# digital transponder
# connectivity
# communication satellite Payloads
# conventional RF bent pipe payloads
# board processing payloads
# definition and subsystem specifications
# RF and digital equipment
# Digital channel processor specifications
# Direct Radiating Array (DRA) Antenna
# High capacity multiple spot beam systems
# Flexible payload
# Multi-Port Amplifier
# link budget calculation
# satellite throughput
# payload
# RF and system payload
# leading multi-disciplinary engineering teams
# oral presentation skills
# French fluency
# Excellent interpersonal skills
# strong work ethic
# our delivery pipelines
# new and emerging software tools
# key performance metrics
# configuration management
# IaC
# template
# 3rd party IP
# procurement
# license
# maintenance renewal
# computing capacity planning
# PCB design
# FPGA
# RF
# Relevant DevOps engineering experience
# continuous delivery pipelines
# agile software development practices
# provision
# audit teams
# scripting languages
# Groovy
# Montréal
# Linux system administration
# troubleshooting skills
# security hardening
# Git/SVN
# (Bitbucket
# GitLab
# Azure Cloud
# Docker and container orchestrators
# configuration management tools
# SQL Databases
# load balancing
# TLS
# GUI tools
# VSphere
# VirtualBox
# DevOps Engineers
# secure infrastructure automation
# a global multi-geography cloud environment
# the team's 24/7 operation
# DevOps automation/infrastructure/product delivery
# practical automation solutions
# custom modules
# cloud architects
# ALM tools
# the right tooling
# a fully automated release management pipeline
# the automated build process
# environment setups
# testing scripts
# deployment
# production operational metrics
# debugging information
# meaningful insights
# microservices
# Active Directory
# datacenters
# other scripting language
# infrastructure provisioning
# scripting language
# quicker issue resolution complex problems
# continuous improvements
# better reliability
# problem recurrence
# all non-exceptional service conditions
# the Azure platform
# Azure technologies
# Compute
# any scripting language
# (PowerShell/Python/others
# similar development repo
# SQL/Cosmos/Mongo/PostGreSQL
# instrumentation
# technical deep dives
# existing technology implementations
# accountability
# the Reliability and configuration management principles
# other technologies stakeholders
#  Conducting workshops
# User journeys
# persona
# the Oracle Siebel technology workspace
# technical design documentation
# Oracle Siebel
# Oracle Policy Automation
# Middleware
# technical work assignments
# user acceptance testing
# conformity
# compatibility
# the Onsite/Offshore model
# desired business outcomes
#  Ensuring performance
# audit
# required approvals
# A bachelor’s degree
# a Siebel designer/developer
# the software development lifecycle
# post-production support handover
# project scoping
# Siebel SOAP Structure
# WSDLs
# XSDs
# XSLT
# XMLs
# Siebel Workflows
# Error/Exception Handling
# Siebel Integration Object structures
# EAI Business Services
# Siebel Configuration
# application performance tuning
# the Siebel Data model
# SQL / Store procedure creation
# Siebel enterprise architecture
# Siebel Open UI
# Java Script
# Siebel Public Sector applications
# tolerant products
# an inclusive team environment
# engineering-specific roadmap items
# other disciplines
# our merchants
# a technical influencer
# quick iterative development
# experimentation analysis
# Technical expertise
# multiple stakeholders
# technical excellence
# Experience designing and developing APIs, web and mobile properties
# Scrum
# Agile team
# an RTOS
# Automated testing
# Agile development environment
# Strong written/verbal communication skills
# Bachelor degree
# Highly motivated, enthusiastic, and a positive thinker
# VxWorks
# RTX64
# RTEMS
# Communications interfaces
# SPI
# EtherCAT
# ATDD
# BDD
# Continuous integration/build automation
# Windows Active Directory
# Azure AD Connect
# Microsoft's Active Directory Domain Services
# AD CS
# Microsoft's Active Directory Federation Services
# AD FS
# AD LDS
# Microsoft's Active Directory Rights Management Services
# RMS
#  Microsoft Azure AD
# MFA
# SSPR
# ATA
# FIM/MIM
#  Microsoft Web Application Proxy
# roadmap
# multi-directory enterprise solution
#  Developing workflows
# system configurations
# technical project documentation
# i.e. technical and configuration runbook
# the enterprise architecture strategies
# ongoing Active Directory security and strategy discussions
# all implementations
# production and non-production environments
# L2/L3 production support
# defect
# Qualifications
# Microsoft Active Directory
# a multi-functional team environment
# good interpersonal skills
# a definite asset
# subject matter expertise
# architectural design
# implementation
# Azure AD Zero Trust components implementation
# Conditional Access
# SAML
# Azure AD proxy
# device authentication
# health validation
# Microsoft’s advanced security and networking services
# Key Vault
# Sentinel
# dynamic and immutable Azure Cloud infrastructure
# Organization/Folder/Project/Resource structures
# the corresponding security solutions
#  Preferable security knowledge
#  Enterprise Mobility + Security (EMS
# Intune
# Conditional Access \ MDM \ MAM
#  Permissions
# Tenant \ Security & Compliance Center
# Archiving
# eDiscovery
# M365 Security & Compliance  Strong PowerShell scripting skills
# ongoing Azure
# Microsoft 365 security and strategy discussions
# IaaS/PaaS/SaaS platforms
# fundamental cloud technologies
# the bachelor level
# information professional designations
# GCP certifications
#  Superior problem solving and decision-making skills
# Scope Key Candidate Skills
#  Encryption and Key Management
# HSM
# Integrated DLP
#  PKI
#  Active Directory
#  VPC Security
#  ATP
#  CASB
#  Management & Automation Tools
#  Configuration Management
#  Logging, Monitoring and SIEM tools
# extraction
# backend software engineering experience
# developer productivity tools
# CI/CD systems
# Observability
# Telemetry tools
# modern, component-based JS frameworks
# component-based UI frameworks
# usability
# product and design lifecycles
# penetration testing
# our Static Analysis orchestrator
# Salus
# security fixes
# security scanners
# development frameworks
# security functionality
# AppSec
# scalable systems
# our backend systems
# a tangible roadmap
# A/B testing frameworks
# Blockchain technology
# a large monolith
# financial, high reliability
# strategic roadmaps
# coding standards
# foundational infrastructure components
# e.g. dynamic configuration
# container orchestration
# elegant solutions
# Wrapbook customer problems
# small approachable tasks
# performant, scalable, and secure software
# Mentoring
# SQL queries
# Rails applications
# SQL indices
# the core architecture roadmap
# high-impact tech initiatives
# fast iteration
# gap
# inefficiency
# testability
# maintainability
# key metrics
# scalable build/test/release infrastructure
# key stakeholders
# Agile or Lean environment
# customer centric approach
# Proven mentor
# Javascript/Typescript
# accessibility
# our proactive experience
# teammate
# technical and product expertise
# Ada’s builder experience organization
# early, ambiguous stages
# clarity
# Ada’s application
# Required Qualifications
# Hadoop ecosystem
# back-end programming - Scala
# Spark jobs
# high-performan ce
# HiveQL
# workflow schedulers
# Hadoop Clusters Proven
# Azure ADLS
# Linux enviroment
# shell scripts
# fine tuning mechanism
# the timings
# Automation opportunities
# the repeated tasks
# Bug fixes
# Required Skills Linux Spark
# SQL Hadoop Ecosystem - Hive
# Tez
# Optional Skills Azure Services Python Autosys
# real-time 2D/3D creators
# their workspaces
# artifact
# artifact management
# workspace management
# file synchronization
# Plastic SCM
# Helm
# dev ops principles
# automated test tools
# AWS products
# cloud deployment
# Excellent written and oral communication skills
# the software/product designers
# quality assurance parameters
# the QA team
# QA test procedures
# the drafting
# the QA process
# Troubleshooting quality issues
# product specifications
# Quality Assurance reports
# the successful deployment
# Automation
# Testing Automation
# overall estimations
# Software Development methodologies
# operational tasks
# toil
#  Drive product reliability improvements
# Kubernetes clusters
# incident postmortems
# production logs
# alert
# MTTR
# SLO targets
# an SRE
# DevOps role
# one or more observability technologies
# VictoriaMetrics
# Datadog
# Zabbix
# SLIs
# SLOs
# SAS programming activities
# project timelines
# high quality outputs
# study timelines
# oversight and effective delegation
# SAS Programming activities
# accurate resource forecasts
# date study documentation
# sponsor
# high quality SAS programs
# tabulation dataset mapping
# analysis datasets
# (TFL) output
# TFL shells
# complex SAS procedures
# Company generic macro usage
# appropriate documentation
# data mapping documentation
# CDISC compliant tabulation
# CDISC therapeutic area standards
# TFL output
# high quality documentation
# tabulation
# accurate project documentation
# Archive deliverable files
# Lead Statistician
# the Lead Statistician
# study milestones
# Lead Biostatistician and Project Manager
# SAS Programming expertise
# departmental and company-wide initiatives
# SAS Programming Subject Matter Expert
# Support SAS Programming process improvement
# SAS Programming Client Account Manager
# the SAS Programming team
# regulatory inspections
# SAS Programming
# Company SAS Programming services
# the SAS Programming group
# customer SOPs
# working familiarity
# progression
# SAS Programmers
# assigned SAS Programming resource
# Accurately record time
# pharmaceutic
# SAS programming experience
# Master’s Degree
# CDISC SDTM
# ADaM Implementation Guidelines
# Excellent organizational skills
# Sponsors
# Strong Analytical mindset
# high quality deliverables
# (e.g., CDISC SDTM
# CDASH
# CDISC standards
# all documentation
# Annotate case report forms
# CRFs
# the CDISC Implementation Guideline
# SDTM
# SDTM specifications document
# CDISC Implementation Guideline
# standardized SDTM migration programming procedures
# quality Standard Data Tabulation Model
# (SDTM) compliant SAS datasets
# XML documents
# (e.g., ADaM) specifications
# any study analysis algorithm
# program specifications
# consultation
# Biostatistical programming and Biostatistical staff
# timeline
# all deliverables
# SAS code
# Listings
# Figures outputs
# correction
# enhancement
# other programmers
# program revisions
# SAS programs
# QC SAS programs
# Dataset
# the departmental QC procedures
# Train and mentor new hires
# junior SAS Programmers
# standardized design and programming procedures
# Define XML
# PDFs
# Reviewers Guides
# CDISC
# dataset programming
# quality improvement initiatives
# standardized programming procedures
# standardized macros
# validation/compliance activities
# Veristat
# statistical analysis outputs
# abstract
# poster
# manuscript
# electronic regulatory submissions
# integrated summaries
# OR Master’s Degree
# verbal/written communication skills
# robust architecture
# real time analytics
# technology and business stakeholders
# repeatable infrastructure
# multiple environments
# Continuous Delivery/Continuous Integration workflow
# .. Containerized workloads
# Python/Go/Bash scripting experience
# Strong Linux Systems Administration Experience
# Managed Apache Airflow
# Kubernetes cluster
# Prometheus and PromQL experience
# Ansible/Puppet/Chef experience
# Concourse/Zuul/Jenkins experience
# Code - Terraform
# gcloud CLI
# auto-scaling & auto-healing Kubernetes clusters
# GKE
# all application deployments
# industry leading logging
# DevOps best practices
# Airflow deployments
# Peer AWS
# seamless multi-cloud strategy
# firewall rules
# data ingestion
# Sqoop
# HBase
# Impala
# Scala Control^M
# medium and significant Complex data Pipelines
# BSTM
# fully automated testing
# automated unit
# Datahub
# Cloud Data platforms
# development design frameworks
# key inputs
# roadmap strategy
# Data Architectures
# exposure o Dimensional Data Modeling
# an inclusive work environment
# Hadoop and Data Engineering space
# Apache Hadoop distributions
# HDFS
# Hbase
# batch
# analytics
# data loading tools
# Flume
# Hadoop Framework
# HBASE
# .
# Workflows
# different file formats
# e.g. AVRO
# ORC
# Parquet
# Jira
# Continuous Integrations tools
# Linux/Mac OS administration
# package management and testing framework
# WorkForce Software experience
# SAP SuccessFactors
# WorkForce Software modules
# A Bachelor’s Degree
# a test automation stack
# well defined test suitesBuild
# the technical stack
# high quality, robust and reusable automation tests
# a varying set
# productsBuild
# the product functionality
# scenario
# functional, regression and system level test activities
# applicationsWork
# a highly collaborative environment
# a robust and efficient system
# product functionalityCommit
# rapid iteration
# reflectionWe
# Xero
# You Bachelor's Degree
# equivalent work experience5+ years experience
# high quality automation tests
# test frameworks
# clear, concise, and comprehensive test plans
# casesKnowledge
# Nodejs
# backbone
# TestCafe
# SeleniumHave
# Continuous Integration systems
# e.g. Jenkins
# AWS CodeBuild)Experience
# automated tests
# RESTful web services
# unit levelExperience
# performance bottlenecksAbility
# their workHave initiative
# a willingness
# the extra mileAbility
# both remote and co-located developers
# other team membersExperience
# Agile/Scrum
# Lean and Agile ways
# well-crafted software
# a better and more versatile programmer
# experimentation
# a challenging many core target environment
# associated automated test cases
# wireless technologies
# embedded systems
# M.Sc
# Interpersonal and collaboration skills
# Assembler
# Gerrit
# Esper’s flagship Esper Enhanced Android
# (“EEA
# customer-driven OS engineering problems
# Esper’s enterprise-grade, security-focused Android OS
# Java / Kotlin / Android apps
# scalable software
# any SCM
# .. Bachelor
# / Master’s degree
# Android framework internals / device bringups
# AOSP
# Linux kernel
# SELinux
# third-party, open-source orgs
# LineageOS
# CTS tests
# CTS-compliant Android platforms
# the telephony layer
# i.e Android RIL
# Triage
# Design workflows
# TD meetings
# a courteous, respectful, professional manner
# humility
# Document workflows
# Maya and Maya scripting
# Nuke and Houdini experience
# Object-oriented Python
# git
# subversion
# mongodb
# shotgun
# (shotgrid
# a renderfarm manager
# 5 to 10 yrs industry experience
# networking technologies
# OSI Model
# TCP/IP, LAN switching
# IP routing and Ethernet networks
# Ixia
# ESXI/Hyper-V/KVM
# VM
# Agile development and testing processes
# wireless protocols
# 802.11ac
# 802.11ax
# WLAN advanced security protocols
# WPA
# WPA2
# WPA3
# RADIUS protocol
# a plus.. Automation experience
# Selenium
# well designed, testable, efficient code
# production AEM systems
# AEM
# a BS/MS degree
# a clever, highly motivated developer
# Sling
# AEM Components
# Sling Models
# OSGi Services
# Servlets
# Methodical approach
# underlying AEM subsystems
# scheduler
# Dialogs
# Templates
# ClientLibs
# the latest frontend tools
# ES6 JavaScript
# Storybook.js
# the forefront
# CDW offerings
# new offerings
# the customer’s infrastructure
# all the stakeholders
# Reviews peer’s designs
# Determines
# proposed hardware and software engagements
# better CDW’s technology leadership
# overall relevance
# standardized templates
# the SOW framework
# demo lab
# services calculation
# Calc
# CDW
# solution implementations
# CDW audiences
# Coaches and mentors team members
# their technical, consulting, and sales skills
# FSAs
# expertise evaluations
# new hire FSAs
# shadow assignments
# new hires
# Advises
# renewal
# contract.)Incorporates financing
# the 5-year roadmap
# ITS Practice (Integrated Technology Solutions) value proposition
# CDW.Guides
# contrast
# all tiers
# CDW technologies
# e.g., Cisco
# McAfee/Juniper
# external competing technologies/solutions
# e.g. Dell
# NetApp
# other FSAs
# CDW customer events
# presentation
# credibility
# large group formats
# the teamDelivers presentations
# assessments improvements
# demo
# Solution Architects
# ISA
# AE
# mapped opportunities
# fine tunes strategies
# a regular cadence
# partner alignment
# geography
# ...
# Containers and Resource Management systems
# infrastructure troubleshooting
# bottleneck problem analysis
# different business domains
# English proficiency
# Java/ Scala
# BashBig Data stack
# ZookeperNoSQL
# Cassandra/ Hbase
# Kafka Streams
# IOT Hub
# Storage Queues
# Stream AnalyticsData Visualization
# QlikViewETL
# Streaming Pipelines
# Apache Oozie
# NiFi
# StreamsetsOperation
# Cluster operation
# Cluster planningSearch
# Elasticsearch/ELKInMemory
# Ignite
# RedisSolid Cloud experience
# 2 or more leading cloud providers
# Cubes
# Visualization
# SageMaker
# Tensorflow)Enterprise Design Patterns
# Component/ Integration Testing
# relational schemas
# SQL optimizationExperience
# various messaging systems
# ZeroMQ/ RabbitMQRest
# SOAPBuild Systems
# SBT
# GradleDocker
# sustainable and efficient solutions
# preferably Angular
# preferably a Bachelor's Degree
# Proficiency and enterprise work experience
# Angular (Angular 2+
# preferably Angular 8)
# websockets
# sc
# Data Technology Consultants
# structured and unstructured data
# both batch & streaming methods
# designing infrastructure
# premise and cloud architectures
# the business analytics teams
# an object-oriented/object function scripting language
# metadata capture
# data cataloging
# message queuing
# Any object-oriented/object function scripting language
# Azure: Storage
# system configuration
# ongoing issue identification
# self-sustaining code
# certification
# flux
# ReduxAngularJSRxJSVirtual
# Real DOMsMVC
# web designRESTful APICI
# the SDLCUnit testing
# an agile development model
# Design & Develop web backend solutions
# actionable form
# strong implementation aptitude
# a scalable solution
# Strong database fundamentals
# various offerings
# data quality metrics/monitoring
# microservice based design
# web backend services
# the appropriate escalation
# ReduxKnowledge
# the Virtual DOMUnderstanding
# MVP patternsCore JavaScriptCSS, HTML
# Adaptive
# web designConsuming
# accessible, semantic markup
# client-side and server-side architecture
# a SCRUM team
# JS, Java
# Core JavaCreational
# Web DesignRESTful
# APICI
# the SDLCUnit TestingDatabases
# Automation Framework
# functional, integration and acceptance test cases
# automation tasks
# test cycles
# Defects documentation
# test automation development
# REST & SOAP API testing
# preferable tool
# SOAPUI
# Groovy Scripting
# agile methodology
# Excellent organizational, troubleshooting and analytical skills
# functional, integration
# Scope and estimate project tasks
# fast and scalable Python code
# web frameworks
# Flask/Django
# Strong SQL knowledge
# AWS\
# An acquaintance
# Strong Linux knowledge
# GPFS
# Configuration management
# (GIT/Stash
# Ganglia
# NFS/SAMBA/GPFS/Lustre
# Provisioning
# Foreman
# RedHat Satellite
# Strong Troubleshooting
# backend reactive programming languages
# lightweight reactive microservices
# webhooks
# asynchronous API design
# a cross functional agile team
# FinTech
# coding standard and other software development best practices
# Enablement
# proactive communication
# critical dependencies
# Spring Batch
# SQLNice
# JMS/MQ
# Splunk/Dynatrace
# CSS3Experience
# preferably ScrumProficiency
# local storageGood experience
# optimize
# complex highly reliable and scalable production systemsFamiliarity
# database conceptsBachelor’s Degree
# Mainframe/Backend Systems - Knowledge
# SmartBear
# Reporting - Jira
# Mainframe Automation
# Serenity
# Excellent communication and documentation skillsEnglish
# B2
# higherClient
# predefined technical specifications
# smart contract security audit team
# public/private testnet
# web3 frameworks
# Smart Contract security audits
# NFT related protocols
# ERC-721
# ERC1155
# Solidity contracts
# L2 networks
# Polygon
# Slither
# Echidna
# Mythril
# talented software engineers
# the HW team
# your SW peers
# new runtime development
# HW bring-up
# runtime diagnostics
# production-quality SW development practices
# embedded driver development
# chipset architectures
# ARM Cortex M4/A7
# various OS environments
# LINUX
# various embedded communication protocols
# IIC
# FPGA development
# ASIC development flow
# objective oriented programming (OOP) design principles
# verilog
# RTL
# SIMD processors
# GPUs
# FPGAs
# a Deep Learning frameworks
# e.g. Pytorch
# your full-stack development skills
# the world's most advanced and life-changing biotech medicines
# creative and ground-breaking software frameworks
# Amgen
# DevOps frameworks
# continuous deployment pipelines
# new drug therapies
# grievous illnesses
# high-quality, scalable, and robust software products
# Informatics solutions
# groundbreaking technologies
# informatics solutions
# High School / GED
# bioinformatics
# cheminformatics
# laboratory automation
# High learning agility
# solution documentation
# detailed resource and completion estimates
# modern coding methodologies
# complex multi-functional projects
# our district technology toolsets
# advanced troubleshooting techniques
# a relevant computer systems/technology application development discipline
# multiple formats
# Office 365 Power Platform environment tools
# data gateways
# SQL reporting
# Hands-on 1hour series
# the change’s impacts
# validation
# supplier/component changes
# customer-initiated changes
# minimized quality risk
# PPAP documentation
# a timely and quality manner
# APQP
# FMEA
# associated Veoneer programs
# prototype builds
# prototype shipments
# NCE-Prototype
# prototype shipment
# the root cause investigations
# the containments
# corrective/preventive actions
# 8D methodology
# Lead PFMEA
# Zero Defect program
# continuous improvement activities
# scrap
# Electrical or Mechanical Engineering Degree
# 8D
# PFMEA
# Strong analytical and communication skills
# TD
# business segment CIO technology areas
# a heightened focus
# troubleshooting incident
# operational availability levels
# planning implementations
# availability targets
# prompt
# controlled and timely incident resolution
# effective and defect-free support
# accurate documentation
# e.g. functional, security, integration, performance, quality, operations
# communicator
# tracker
# escalator
# Monitor system life cycles
# both specs
# functionality support business objectives
# meaningful metrics
# performance and resource utilization
# RFI/RFP
# SLAs
# Undergraduate Degree
# Adeptness
# upgrade
# Strong subject matter expertise
# highly complex troubleshooting/problem resolution
# highly complex and/or comprehensive applications/systems
# targeted and controlled remediation plans
# Readiness
# TD services
# analytical tools
# new innovations
# Skillsets Required
# Now related configurations
# one or more ServiceNow Platform areas
# SQL/NoSQL database
# 5G RAN
# OAM
# all software verification / integration
# software regression test environments
# contracted design work
# third-party partnerships
# OEM solutions
# 5G networks
# the open RAN ecosystem
# compelling customer value
# real network deployments
# eNodeB/gNodeB Software
# , IPSec
# SCTP
# Precision Timing Protocol
# PTP
# hardware accelerators
# Fronthaul
# Midhaul
# Backhaul
# 4G/5G SW development experience
# Carrier grade Transport solution
# the DU functionality
# Organized, goal-oriented, self-starter
# a collaborative team environment
# Demonstrable C/C++ programming experience
# streaming technologies
# strong partnerships
# containerized and serverless microservices
# scalable AI prototypes
# AWS IoT
#  Build high volume/high-frequency data loading and transformation processes
# various initiatives
# building backend data services
#  Experience building high scale Event-Driven Architecture
#  AWS services
# RDS, S3
# EKS/ECS
#  Design ML& AI solutions
#  Build ML applications
#  Build ML models
# Python frameworks
# Python Data Science Libraries
# Data Analysis/Data Cleaning/Feature Engineering/Modelling/Testing/Validation
#  Time Series Modeling
#  AWS
# Sagemaker/Step Function/ECS/Lambdas
#  Optimize system resources
# video processing capabilities
# warp
# algorithm teams
# various interfaces
# our camera processor
# 3rd party middleware
# firmware development
# constrained environments
# RTOS environments
# real-time embedded issues
# Board Software Packages
# BSPs
# SPI and Ethernet protocols
# graphics API
# OpenVG
#  AUTOSAR system development experience
# automotive or other safety-critical industries
# various cryptographic authentications
# hash
# encryption algorithms
#  Coordinate
# incoming requirements
# Champion core DevOps behaviors
# an Azure environment
# Azure Certifications AZ-900
# AZ-203
# NodeJs applications
# Octopus Deploy
# either Azure DevOps
# GitHub Enterprise
# the Atlassian Stack (JIRA
# git repositories
# branching strategies
# some Java
# occasionally Ruby
#  AWS primitives
#  Kotlin
# your local and broader practice
# efficient and optimized code
# iOS-based solutions
# specifically native iOS development
# Swift/Objective-C.
# native iOS development lifecycle
# operating system API
# update
# OOP, SOLID, Design Patterns
# common mobile application architecture patterns
# (RxSwift
# Experience consuming web services
# the Android development lifecycle
# reactive programming
# newly implemented Azure applications
# Azure environments
# current and emerging Azure services
# the Azure service implementation
# Geography
# ArcMap
# other GIS applications
# your expert SQL and data modeling skills
# the data warehouse base layer data models
# Sonder's reporting dashboards
# the company’s data lake/data warehousing strategy
# product and business analytics teams
# product analytics
# Sonder’s business
# Sonder’s business KPIs
# scalable platforms
# feature extraction
# inbound requests
# Expert Python coding skills
# Expert SQL and data modeling skills
# data warehouse principles
# ETL jobs
# data warehouse stores
# the technical mentor
# the technical liaison
# quarterly goals
# the team's deliverables
# Commercial and Leadership/Mentorship exposure
# Fullstack development
# Strong Frontend background
# React/Redux
# Strong Backend background
# a highly scalable cloud application architecture
# the 24x7 availability
# build and deployment scripts
# change workflows
# cloud infrastructure compliance
# Research new cloud and software technologies
# Complete self-paced and online professional training
# public cloud certifications
# 2+ years Linux Operating system administration
# e.g. CloudFormation
# site reliability
# failover/disaster recovery
# network-based protocols
# a degree/diploma
# Current AWS certifications
# product designers
# RideFlag applications
# an agile, sprint-based methodology
# the VIPER architecture pattern
# initial specification
#  Excellent teamwork
# VIPER design pattern
# well-designed, verified, documented and defect-free software
# tasks planning and scheduling skills
# DDP
# Docker/Container
# committed project deadlines
# (i.e., Red Hat OCP
# MOBIA clients
# various client engagements
# consultant mindset
# MOBIA
# lockdown
# (i.e., OCP) solution implementation
# Red Hat OpenShift
# Red Hat OpenStack
# Google Anthos
# PaaS solutions
# exceptional client experience
# strong verbal, written, and listening skills
# pre-sales solutioning
# the following cloud technology platforms
# site reliability engineering
# HashiCorp stack
# (i.e., Terraform
# Bilingual (French/English) language
# a definite Plus
# USB interface
# the VITA
# IVI
# multimeter
# Self-starter/motivator
# Outstanding work ethic
# organizational success
# Computer Networking
# Public Cloud Stacks
# MSAZ
# Public Cloud Networking
# a TELCO world
# Wireline
# CDN technologies
# communications protocols
# BGP, ISIS
# Segment Routing
# EVPN
# etc.)﻿. Strong aptitude
# Bilingual - French/English
# CI/CD tooling
# e.g. Gitlab Pipeline
# ARM Templates
# GCP Templates
# inbound/outbound (inter & intra region
# traffic optimization
# lean agile methodologies
# Workplace culture enthusiast
# endpoint fleet management automation
# laptop
# a lifecycle management plan
# the endpoint management
# windows patching
# hardware specs
# Infrastructure and Cybersecurity teams
# O365 environment
# troubleshooting/resolution
# reliability Administration
# unified collaboration platform build
# a hybrid Azure AD/O365
# OneDrive
# OS deployment configuration
# WIM files
# Driver Packages
# Customized Task Sequences
# UEFI/BIOS
# Registry Configuration
# the organization's endpoint encryption
# client configuration integrity
# incremental versioning
#  Maintain and document desktop configuration standards
# organizational security policies
# technical and standard operating procedure documentation
# desktop hardware
# service packs
# security configurations
# image deployment
# testing and validation efforts
# desktop software license usage
# hardware compliance
# hosted application software distribution
# Azure Virtual Desktop..  Design
# Video Conferencing systems
# boardroom
# managing escalations
# modern workplace community
# Bayshore EA standards
# XDR technologies
# ATP
# task sequences
# Windows 10 OS and associated services
# AAD
# Azure MFA
# SSO Apps
# AAD connect
# conditional access
# M365 tenant/applications
# ProPlus
# Enterprise Mobility
# Smartphones
# tablet
# O365 solution design
# DMZ architecture
# network troubleshooting
# federated services
# application exploits
# Security and Privacy Frameworks
# PIPEDA
# PHIPA
# SOC2
# Microsoft Graph
# IaaC
# Ansible/Terraform
# an automation
# Microsoft O365
# Modern Desktop Administrator Associate
# Identity Fundamentals
#  Managing endpoints
# code-based configuration management tools
#  Supporting video collaboration platforms
# Logitech
# Poly..  Design
# Azure Virtual Desktop
# general mathematical calculations
#  Proven analytical, evaluative, and problem-solving abilities
#  Exceptional customer service orientation
# a closely-knit, high performance team
# an accredited school
# service assurance
# fulfillment application
# Java/JavaScript/Groovy/Python
# network automation
# containerized microservices applications
# highly motivated and talented software engineers
# the WaveSuite product suite
# object oriented programming
# IntelliJ/Eclipse/Visual Code/WebStorm..  Experience
# MacOS X
# Cypher query language
# superior UI designs
# a reusable set
# Java RESTful APIs
# stable, reliable and effective databases
# Strong UI development
# JS Framework
# RESTful Java APIs
# Microservices Architecture
# Strong SQL coding skills
# , fast learner
# excellent interpersonal skills
# Strong problem-solving skills
# : Proficiency
# C#, ASP.NET framework
# DotNet Core
# MVC/Razor page
# Net WebAPI
# HTML/SASS/CSS
# front end UI frameworks
# MS SQL database development
# Strong design and coding skills
# quality SaaS products
# QA teams
# the software modules
# efficient and legible code
# QA time
# the sprint
# mentor junior developers
# hands-on full-stack development work experience
#  Langages
# J avaScript
# J SON et PowerShell
#  Banques de données
# exploitation
# different mandates
# varied expertise
# specific analyses
# a master's degree
# data enhancement purposes
# PowerBI or data visualization tools
# agile mode
# Full lifecycle application development
# the software suites
# Angular, Java
# HL7 FHIR
# public and private cloud stack
# a teamwork environment
# existing enterprise architectures
# organizational goals
# functionally accurate and modular application programs
# approved design specifications
# a program's functionality
# its specification's business requirements
# SPA application development
# Angular, Bootstrap
# HTML/CSS/JS, ES6
# OpenID Connect
# integration environments
# RedHat OpenShift
# n-tier architectures
# (UI, Business Logic Layer
# basic waterfall
# iterative project management concepts
# (Agile/Scrum
# web test automation frameworks
# HL7
# A completed Bachelor's degree
# Actuarial Science
# a completed Master's degree
# credit risk parameters
# ICAAP models
# IFRS
# the calculation
# Basel II
# SAS Base
# SAS EG
# .. Bilingualism
# a clear and intuitive manner
# intermediate level coder
# LCHH format/model
# HTML/CSS/PhP
# no onboarding
# finance/fintech companies
# scalable, maintainable solutions
# rigorous peer review
# automated integration tests
# a skilled software craftsperson
# surf
# QA specialists
# Accomplishments
# a Scrum/Kanban environment
# Microsoft Azure cloud development experience
# Perks
# an Agile, cross-functional team
# MVP releases
# clockwork
# the customer's, company's, team
# the collective brilliance
# M2M interfaces
# a microservices environment
# relational (RDBMS) databases
# NoSQL/KV Stores
# Messaging Queuing Services
# GitHub use
# Results-oriented, data-driven, experimental attitude
# Boundless positivity
# Strong troubleshooting and problem-solving skills
# Statflo
#  Accommodations
# the recruitment selection process
# Roku applications development
# Roku applications
# Brightscript Scenegraph
# beneficial (HTML/JS
# Swift/Objective-C
# Server-side scripting skills
# Bitbucket / Git
# Agile, Continuous Integration
# CMIS
# related documentation
# notably the register map
# the underlying transceiver code software
# C / embedded software
# telecom product
# Leadership qualities
# Actalent
# all applicants
# Self-motivated, enthusiastic and strong drive
# negotiation

# %%
for word in tech_list:
    print(wnl.lemmatize(word,get_pos(word)))
# Out:
# !Trak-it Solutions !Trak-it HR
# .com
# .htaccess
# .NET
# .NET CLR
# .NET Compact Framework
# @Road GeoManager
# @Task
# 10 Key
# 100 Plus Hatch Pattern Library
# 1003 Uniform Residential Loan Application
# 1031 Exchanges
# 1099 ProsSoftware
# 1CadCam Unigraphics
# 1H NMR
# 1ST Pricing Window & Door Toolkit
# 20-20 Technologies 20-20 Design
# 21 CFR
# 21 CFR Part 11
# 21st Century Skills
# 24SevenOffice Project
# 2AB iLock Security Services
# 2D graphics
# 360 Analytics eQUEST
# 360 Degree Assessment
# 360 Feedback
# 360-degree video
# 37Signals Basecamp
# 3Com NBX
# 3D Animation
# 3D Architectural Rendering
# 3D Design
# 3D GIS
# 3D graphic design software
# 3D Graphics
# 3D graphics software
# 3D Model Maker
# 3D Modeling
# 3D Modelling
# 3D motion analysis software
# 3D Nature LLC Visual Nature Studio
# 3D Nature LLC World Construction Set
# 3D Printing
# 3D Printing software
# 3D Rendering
# 3D Scanning
# 3D Seismic Interpretation
# 3D Static Strength Prediction Program 3DSSPP
# 3D Studio Max
# 3D Studio Viz
# 3D Systems Geomagic Design X
# 3D Systems GibbsCAM
# 3D urban simulation modeling software
# 3D Visualization
# 3DGrid HIPAA Checkup
# 3dMapper
# 3ds Max
# 3M Electronic Monitoring
# 3M Encoder
# 3PL Central
# 401k Rollovers
# 4D
# 4hana datasource extraction
# 4hana development experience
# 4hana experience
# 4n6xprt Systems StiffCalcs
# 4th Dimension
# 5 Why
# 5.1 Mixing
# 5AM Glassbox Translational Research
# 5G Optical/Fiber Network Planning
# 5G Product Management and Orchestration
# 5G Radio Access Network Engineering
# 5G Radio Access Network Operations
# 802.11 Security
# 80-20 Software Leaders4
# 911 system information databases
# 960 Grid System
# a la mode Pocket TOTAL
# a la mode WinTOTAL
# A Large Outdoor Fire plume Trajectory model Flat Terrain ALOFT-FT
# A mathematical programming language AMPL
# A programming language APL
# A&D Technology iTest
# A1-Law
# A3 Thinking
# AAAHC
# AABACH Graphic Systems DIGRA
# AAC
# AACR2
# AAMS
# AAP
# AAR
# AASHTO
# AASoftTech Web Organization Chart
# AAT
# AAUS Scientific Diver
# Ab Initio
# Abacus
# Abacus Data Solutions HearWare
# Abacus Data Systems AbacusLaw
# Abacus Tax
# AbacusLaw
# Abandonment
# ABAP
# ABAP (BAPI)
# ABAP Web Dynpro
# ABAP-OO
# Abaqus
# Abatement
# ABB 800xA
# ABB CPM4Metals
# ABB MicroSCADA Pro DMS
# ABB MicroSCADA Pro SYS
# ABB Optimize IT Predict & Control
# ABB Production Planning
# ABB PSGuard
# ABB RobotStudio
# Abbot
# Abbot Informatics STARLIMS
# AbbottSoft QuickFix
# ABBYY
# ABBYY FineReader
# ABC Analysis
# ABC Compiler
# ABC Flowcharter
# ABC programming language
# ABC: the AspectBench Compiler for AspectJ
# ABCP
# Abdominal
# Abdominal Imaging
# ABEL
# ABELSoft ABELDent
# Abelton
# Abend-Aid
# ABI
# Abilis CORIS Offender Management System
# Ability Photopaint
# Abis
# Ableton
# Ableton Live
# ABLS
# Abnormal Psychology
# ABO Certified
# ABOL Manifest Systems
# Aboriginal Affairs
# Aboriginal Health
# Aboriginal Law
# Aboriginal Relations
# Above the Line
# ABR
# Abra
# Abra Suite
# Abrasives
# Abraxas Energy Consulting Metrix
# Abrevity FileData
# ABS
# Absenteeism
# Absolute Return
# Absorption
# Absorption process simulation software
# Absorption Spectroscopy
# Abstract Algebra
# Abstract Expressionism
# Abstract Paintings
# Abstracting
# Abstraction
# Abstraction plus reference plus synthesis A++
# Abstracts
# Abundance
# Abuse Prevention
# ABV
# AC Nielsen
# AcaClone pDRAW32
# ACAD
# Academia
# Academic Achievement
# Academic Administration
# Academic Advising
# Academic Background
# Academic Development
# Academic Editing
# Academic educational software
# Academic English
# Academic Journals
# Academic Libraries
# Academic Medical Centers
# Academic Medicine
# Academic Program Development
# Academic Program Management
# Academic Publishing
# Academic Research
# Academic Support Services
# Academic Tutoring
# Academic Writing
# Acarda CallAssist
# Acarda ForbiddenCalls
# Acarda Sales Technologies Acarda Outbound
# AcaStat Software
# ACBS
# ACCA Manual J
# Accela KIVA DMS
# Accela PERMITS Plus
# Accela Tidemark Advantage
# Accelerated life testing software
# Accellos Real Dispatch
# Accelrys Cerius2
# Accelrys DeCipher
# Accelrys FELIX
# Accelrys Insight II
# Accelrys Materials Studio
# Accelrys Pipeline Pilot
# Accelrys QAUNTA
# Access
# Access Control
# Access Dimensions
# Access Gateway
# Access Lists
# Access management software
# Access Points
# Access Software AIRPAX
# Access to Justice
# AccessData Certified Examiner
# AccessData FTK
# Accident Investigation
# Acclaim Legal Acclaim DepoManage
# Account Management
# Account management software
# Account Reconciliation
# Account Segmentation
# Accountants
# Accountants Templates JAZZ-It!
# AccountantsWorld Payroll Relief
# Accounting
# Accounting compliance software
# Accounting fraud detection software
# Accounting software
# AccountMate Software AccountMate
# Accounts Payable
# Accounts Payable &amp; Receivable
# Accounts payable software
# Accounts Receivable
# Accounts receivable software
# Accounts receivables system software
# Accra Med Software Filopto
# Accredited Buyer Rep
# Accredited Cruise Counselor
# Accretion/dilution
# Accruals
# ACCUCert
# Accuity EPICWare
# Acculaw Court Reporters Billing Scheduling Job Management System ABSMS
# Accurate NXG
# Accuship Star System
# Accutech Systems Corporation AccuFarm-MGR
# AccuWeather Galileo
# Accvision ABMIS
# ACD
# ACD Management
# ACD Systems Canvas
# ACDSee
# ACE
# ACE Certified
# ACE Certified Personal Trainer
# ACE Dental
# Acer Hardware
# Acess
# AceTools.biz Ace Translator
# ACF2
# ACFE
# ACH
# Achieve Global
# Achieve Global Certified
# Achieving Measurable Results
# Achieving Your Highest Priorities
# ACI Appraiser's Choice
# ACI Codes
# ACI TaskTracker
# Acid Mine Drainage
# Acid Pro
# Acidizing
# ACIS
# Acknowledgements
# ACL Analytics
# ACL Audit Exchange
# ACL Business Assurance Analytics
# ACLS
# ACLS Instruction
# AcmeStudio
# ACMS
# ACMS Casewatch Millenium
# Acne
# Acne Treatment
# ACOA
# ACOM Solutions RAPID EMR
# Acomba
# Aconex
# ACORD
# AcornSystems Corporate Performance Management
# AcorynSystems Activity Based Costing/Management ABC/M
# Acoustic
# Acoustic Emission
# Acoustic Guitar
# Acoustic Measurement
# Acoustic Modeling
# Acoustica Mixcraft
# Acoustical
# Acoustical Ceilings
# Acoustics
# ACP
# ACPI
# Acquired Brain Injury
# ACR
# Acreage
# Acrendo A.I.med
# Acrendo Medical Software Family Practice EMR
# Acrendo Medical Software Ob/Gyn EMR
# Acresso InstallAnywhere
# Acrobatics
# Acronis
# Acronis Recovery Expert
# Acronis True Image
# Acrylic
# Acrylic Painting
# ACS Technologies ACS Financial Suite
# ACS Technologies HeadMaster
# ACSA
# ACSC
# ACSLS
# ACSM
# ACSM Health Fitness
# ACSP
# ACSR
# ACSS
# ACT Contractors Forms
# ACT CRM
# ACT Discover
# ACT WorkKeys
# ACT! ACT4Advisors
# ACT! Premium
# Act-3D Quest3D
# Actano Rplan
# Actimize Brokerage Compliance Solutions
# Acting
# Action Learning
# Action Oriented
# Action Sports
# ActionScript
# ActionWare
# Activant Solutions Activant Prophet 21
# Activated Sludge
# Active Adult Communities
# Active Data Online WebChat
# Active Directory
# Active Directory Experience
# Active directory software
# Active DoD Secret Clearance
# Active Network EventRegister
# Active Pharmaceutical Ingredients
# Active Shooter
# Active Top Secret
# Active TS/SCI Clearance
# Active-HDL
# ActiveMQ
# Activities of Daily Living
# Actix
# Actsoft Comet
# Actsoft Comet Tracker
# Actuarial Exams
# Actuarial Science
# Actuarial Systems Corporation AIM
# Actuarial Systems Corporation Compliance Testing System
# Actuarial Systems Corporation Defined Benefit System
# Actuarial Systems Corporation Document Generation and Management System
# Actuarial Systems Corporation DV Direct
# Actuate BIRT
# Actuate DocBook
# Actuate Eclipse BIRT
# AcuBase Pro
# AcuityPro
# Acunetix
# AcuPartner Professional
# Acupressure
# Acupuncture
# AcuStaf
# Acute
# Acute Care
# Acute Coronary Syndrome
# Acute Pain Management
# Acute Rehabilitation
# Acutonics
# Acxiom Data Analytics
# Ad Cast
# Ad Exchanges
# Ad Hoc Networks
# Ad Hoc Reporting
# AD OPT Altitude
# Ad Planning / Buying
# Ad Targeting
# Ada
# ADA Compliance
# Ada programming
# ADABAS
# Adapt It
# Adaptable Database System (ADABAS)
# AdaptaSoft CyberPay
# Adaptation
# Adapter
# Adaptive conjoint analysis ACA software
# Adaptive Control
# Adaptive Equipment
# Adaptive Filtering
# Adaptive Leadership
# Adaptive Learning
# Adaptive Metadata Manager
# Adaptive Optics
# Adaptive optics AO simulation software
# Adaptive Planning
# Adaptive Reuse
# Adaptive Streaming
# Adaptive Systems
# Adaptive Technology
# ADAPT-Modeler
# ADB
# ADB Adapter
# ADC Legal Systems Perfect Practice
# ADCs
# Addiction Medicine
# Addiction Psychiatry
# Addiction Recovery
# Addictive Disorders
# ADDIE
# Adding Machine
# Addison Health Systems WritePad
# Addison Health Systems WritePad EMR Systems
# Additive Manufacturing
# Additives
# ADDM
# Address Management System AMS
# Addressing software
# ADE
# ADEA
# Ademco
# Ademero Content Central
# Adenovirus
# Adept problem-solver
# Adept Scientific GRAMS
# Adeptia ETL Suite
# Aderant
# Aderant CompuLaw
# ADERANT Expert Back Office, Powered by Keystone
# ADERANT Expert Matter Center
# Adexa eGPS Suite
# Adexa Supply Chain Planning
# ADF
# ADFS
# ADFS 2.0
# Adgooroo
# ADHD Coaching
# Adherence
# Adhesion
# Adhesive Bonding
# Adhesives
# Ad-hoc
# ADI
# ADi SmartBOL
# ADINA
# Adjudication
# Adjustable
# Adjusters
# Adjustment Disorders
# Adjustment Of Status
# Adjustments
# Adjuvants
# ADK
# ADL
# ADL Data Systems OptimumClinicals Electronic Health Record
# Adlib Express
# Adlib Information Systems Adlib Archive
# ADM
# Administration
# Administration Jobs
# Administrative Assistance
# Administrative Law
# Admissions
# Admissions, discharge, and transfer ADT software
# ADMS pollution modeling software
# ADO
# ADO.NET
# Adobe Acrobat
# Adobe Air
# Adobe Audition
# Adobe Bridge
# Adobe Captivate
# Adobe ColdFusion
# Adobe Connect
# Adobe CQ
# Adobe Creative Suite
# Adobe Design Programs
# Adobe Designer
# Adobe Digital Publishing Suite
# Adobe Director
# Adobe Dreamweaver
# Adobe Edge
# Adobe eLearning Suite
# Adobe Encore
# Adobe Experience Manager - Communities
# Adobe Fireworks
# Adobe Flash
# Adobe Freehand
# adobe illustrator
# Adobe InDesign
# Adobe Lightroom
# Adobe LiveCycle Designer
# Adobe Muse
# Adobe Photodeluxe
# Adobe Photoshop
# Adobe Premiere Pro
# Adobe Professional
# Adobe SiteCatalyst
# Adobe Software Compliance Audit
# Adobe Systems Adobe Acrobat
# Adobe Systems Adobe Acrobat Pro Extended
# Adobe Systems Adobe ActionScript
# Adobe Systems Adobe After Effects
# Adobe Systems Adobe AfterEffects
# Adobe Systems Adobe AIR
# Adobe Systems Adobe Audition
# Adobe Systems Adobe Authorware
# Adobe Systems Adobe Captivate
# Adobe Systems Adobe Cold Fusion
# Adobe Systems Adobe ColdFusion
# Adobe Systems Adobe Connect
# Adobe Systems Adobe Contribute
# Adobe Systems Adobe Creative Cloud
# Adobe Systems Adobe Creative Suite
# Adobe Systems Adobe Director
# Adobe Systems Adobe Distiller
# Adobe Systems Adobe Dreamweaver
# Adobe Systems Adobe eLearning Suite
# Adobe Systems Adobe Experience Manager (AEM)
# Adobe Systems Adobe Fireworks
# Adobe Systems Adobe Flash
# Adobe Systems Adobe Flash Lite
# Adobe Systems Adobe Flash Player
# Adobe Systems Adobe Flex
# Adobe Systems Adobe FrameMaker
# Adobe Systems Adobe FreeHand
# Adobe Systems Adobe FreeHand MX
# Adobe Systems Adobe Human Capital Application Solution Accelerator
# Adobe Systems Adobe Illustrator
# Adobe Systems Adobe ImageReady
# Adobe Systems Adobe InCopy
# Adobe Systems Adobe InDesign
# Adobe Systems Adobe LifeCycle Enterprise Suite
# Adobe Systems Adobe LifeCycle ES
# Adobe Systems Adobe LifeCycle Production Print ES3
# Adobe Systems Adobe LiveMotion
# Adobe Systems Adobe Macromedia HomeSite
# Adobe Systems Adobe PageMaker
# Adobe Systems Adobe Persuasion
# Adobe Systems Adobe Photoshop
# Adobe Systems Adobe Photoshop Lightroom
# Adobe Systems Adobe PostScript
# Adobe Systems Adobe Premiere Pro
# Adobe Systems Adobe Presenter
# Adobe Systems Adobe Reader
# Adobe Systems Adobe RoboHelp
# Adobe Systems Adobe Shockwave Player
# Adobe Systems Adobe Writer
# Adobe Systems AdobeMlashMX
# Adobe Systems Macromedia Shockwave Player
# Adobe Test & Target
# Adobe XD
# Adolescent Therapy
# Adolescents
# Adoption
# ADP Drive DMS for Accounting
# ADP Employease
# ADP Enterprise eTime
# ADP Enterprise HR
# ADP Enterprise HRMS
# ADP eTIME
# ADP E-Time
# ADP ezLaborManager
# ADP Globalview HCM
# ADP HR/Benefits Solution
# ADP HR/Profile
# ADP HRB
# ADP Pay eXpert
# ADP Payforce
# ADP Payroll
# ADP PC/Payroll
# ADP ReportSmith
# ADP software
# ADP Super Report Writer
# ADP Workforce Now
# ADP/Vantra VOLTS
# ADR Recording
# AdRelevance
# Adrenal Fatigue
# Adrenaline
# ADRs
# ADS Advantage
# ADS-B
# Adsense
# AdSense Tracker
# ADSI
# ADSL
# ADSO
# Adsorption
# Adstra Systems ADSTRA Management
# ADT
# Adtec Agency Manager
# Adtech
# AdTrack Customer Acquisition Management CAM
# Adtran
# ADUC
# Adult ADHD
# Adult CPR
# Adult Development
# Adult Education
# Adult Fiction
# Adult Learning Methodologies
# Adult Learning Theory
# Adult Literacy
# Adult Social Care
# Adult Stem Cells
# Adult Students
# Advance Ortho Systems Program Director
# Advanced boolean expression language ABEL
# Advanced business application programming ABAP
# Advanced Chemistry Development ACD/1D nuclear magnetic resonance NMR processor
# Advanced Chemistry Development Analytical Laboratory
# Advanced computer simulation language ACSL
# Advanced Data Systems MedicsDocAssistant for Pediatrics
# Advanced Data Systems MedicsRis
# Advanced Dimensional Management 3D-GD&T
# Advanced Graphics Technology ProCogo
# Advanced Logic Technology WellCAD
# Advanced Management Systems Software for Wineries
# Advanced Micro Systems 1099-Etc
# Advanced numerical software
# Advanced Persistent Threats
# Advanced Portfolio Technologies Report Builder
# Advanced Portfolio Technologies Simulator
# Advanced Processing and Imaging OptiView ECM
# Advanced Retail Management Systems Retail Pro
# Advanced technologies and oceanic procedures ATOP
# Advanced Technologies Class Act
# Advanced Veterinary Services Ranch Vision
# Advanced Visual Systems AVS/Express
# Advantage Information Systems The Agency Advantage
# Advantage Signature Marketing Group Web Master
# Advantage Software Chiropractic Advantage
# Advantage Software Physical Therapy Advantage
# Advantage Software Podiatry Advantage
# Advantage Software Psych Advantage
# Advantage Software Total Eclipse
# AdvantageLaw WinVantage
# Advantos Systems DataTrust Enterprise
# Advent Axys
# Advent Geneva
# Adventure Racing
# Adventure Travel
# Adversarial Simulation
# Advertisement Design
# Advertising
# Advertising Agency
# Advertising Research
# Advertising Sales
# AdviceAmerica AdvisorVision
# Advising People
# Advisory Boards
# Advisory World ICE
# ADX
# Adxstudio, for Microsoft
# AEA
# AEC Design Group CADPIPE
# AEC Software FastTrack
# AEC Software FastTrack Schedule
# AEC Software FastTrack Schedule for Windows
# AED
# AEMC DataView
# Aeration
# Aerial Cinematography
# Aerial Lifts
# Aerial Photography
# Aerial Silks
# Aerial Surveys
# Aeroacoustics
# Aerobics
# Aerodynamics
# Aeroelasticity
# Aerohive
# AeroHydro MultiSurf
# Aeronautical Engineering
# Aeronautics
# AERONET calculator
# AeroPlanner
# Aerosol Science
# Aerospace
# Aerospace Engineering
# Aerospace Industries
# Aerospace Manufacturing
# Aerospace Medicine
# Aerospace Structures
# Aerotriangulation adjustment software
# AES
# AES MailSTAR
# AESDirect
# Aesthetic Surgery
# Aesthetics
# Aestiva Employee Time Clock
# Aestiva Purchase Order
# AetherPalm InfusiCalc
# AFAA
# AFAA Certified Personal Trainer
# Afaria
# Afcom Datasafe Computer Services FlexiBake
# AFDX
# AFE
# Affiliate Management
# Affiliate Marketing
# Affiliate Networks
# Affiliated Computer Services ACS FIREHOUSE
# Affinity Chromatography
# Affirmative Action
# Affordable Care Act
# Affordable Housing
# Afghanistan
# AFIS
# AFLP
# AFM
# African Affairs
# African American History
# African American Literature
# African American Studies
# African Art
# African Dance
# African Development
# African Diaspora
# African History
# African Markets
# African Studies
# Afrikaans
# AFS
# AFT Fathom
# After Action Reviews
# After Dinner Speaking
# After Effects
# After FX
# After School Programs
# After the Deadline
# Aftersales
# AFTRA
# Ag Connections Land.db
# Ag Leader Technology SMS Advanced
# Agarose Gel Electrophoresis
# AGCO Advanced Technology Solutions Fieldstar
# AGCO GTA Software Suite
# AgData Blue Skies Accounting
# Age progression software
# Agency Coordination
# Agency management software
# Agency Management Systems AMS 360
# Agency Master
# Agency MBS
# Agency Relations
# Agency Relationship Management
# Agency Software AgencyPro
# AgencyPro
# Agenda Development
# Agent Business Builder
# Agent-based Modeling
# Agents
# Agevo Farm Manager
# Agglomeration
# Aggregate Planning
# Aggregate Spend
# Aggregates
# Aggregation
# Aggregator
# Aggressive Marketing
# AGI 32
# Agile &amp; Waterfall Methodologies
# Agile Application Development
# Agile Design & Delivery
# Agile Development
# Agile DSDM
# Agile Environment
# Agile Leadership
# Agile Methodologies
# Agile Modeling
# Agile Product Lifecyle Management PLM
# Agile Project Management
# Agile Testing
# Agile Web Development
# Agilent
# Agilent ADS
# Agilent Advanced Design System ADS
# Agilent CGH Analytics
# Agilent ChemStation
# Agilent Technologies GeneSpring GX
# Agilent VEE
# AgileView Software SmartView
# Agiliance Compliance Manager
# Agility
# AgInfoLink Meat Inventory Tracking System MITS
# Aging in Place
# Aging Reports
# Agoraphobia
# A-GPS
# Agribusiness
# Agricultural Economics
# Agricultural Lending
# Agricultural Machinery
# Agricultural Marketing
# Agricultural Research
# Agriculture
# AgriSoft/CMC AgriSoft/ERP
# Agrochemicals
# Agronomic modeling software
# Agronomy
# Agtek
# AgTerra Technologies AgTrac
# AHA
# AHDL
# AHLTA
# AHP
# AHU
# AHWD
# Ai Squared ZoomText
# AIA
# AIA Billing
# AIA Documents
# AIAG
# AIC
# AICC
# AICP
# Aid Effectiveness
# AIDC
# AIF
# AIG OASIS
# Aikido
# AIMSUN
# AIMSweb
# AIN
# Aipotu
# AIQ Systems TradingExpert Pro
# Air Compressors
# Air Conditioning
# Air dispersion modeling software
# Air Duct Cleaning
# Air Force
# Air Freight
# Air Quality
# Air quality modeling software
# Air Sampling
# Air Separation
# Air Source Heat Pumps
# Air Traffic Control
# Airbnb
# Airbrush
# Aircraft
# Aircraft Design
# Aircraft Maintenance
# Aircraft noise monitoring system software
# Aircraft regulation databases
# Aircraft Systems
# Airframe
# Airline global distribution systems GDS software
# Airline Management
# Airline Pilots Daily Aviation Log PPC
# Airline Pilots Daily Aviation Logs PPC
# Airline Reservations
# Airline Ticketing
# Airlines
# AirMagnet Enterprise
# AIRMaster+
# Airport Management
# Airports
# AirSmith FlightPrompt
# Air-Trak Cloudberry
# Airwatch
# Airworthiness
# Ais
# AISC
# AIX 5.x
# AIX Administration
# AJAX
# AJAX Frameworks
# AJAX Toolkit
# Ajax4JSF
# Akamai
# Akka
# Aknaf ADVANTAGE Salon Software and Spa Software
# AKTA
# Alara CRystalView
# Alarm Management
# Alarm management system software
# Alarm system software
# Alarm Systems
# AlarmPoint
# ALARP
# Albanian
# Album Production
# ALC
# Alcatel
# Alcestis
# Alchemy
# Alchemy Catalyst
# Alchemy Systems SISTEM
# ALCO
# Alcohol Awareness
# Alcohol Licensing
# Alcoholic Beverages
# Aldata Warehouse Management
# Aldec
# Aldelo Systems Aldelo for Restaurants Pro
# Aldon
# Aldus FreeHand
# ALE
# Aleph
# Alert Technologies OpsCenter
# Alerton
# Alerton Ascent Compass
# Alexa
# Alexander Technique
# ALF
# Alfresco
# Alfresco Software Alfresco
# Algae
# Algebra
# Algebraic Geometry
# AlgoLab Raster to Vector Conversion Toolkit
# Algor
# Algorithm
# Algorithm Analysis
# Algorithm Compu-Ceph
# Algorithm Design
# Algorithm Development
# Algorithm Optimization
# Algorithmic language ALGOL
# Algorithmic software
# Algorithms
# Alias Automotive
# Alias Studio Tools
# Alias Wavefront Design Studio
# Alibaba
# Alibre Design
# Alienbrain
# Aline GRC
# Aljex Inventory
# ALK Technologies FleetSuite
# ALK Technologies PC*Miler
# Alkalinity
# Alkylation
# Allaire ColdFusion
# Allegro
# Allegro Landmark
# Allen Bradley PanelView
# Allen-Bradley
# Allergenic diet software
# Allergic Rhinitis
# Allergy
# Alliance Automotive Shop Controller
# Allied Financial Software Act4Advisors
# Allied Health
# AllNetic Working Time Tracker
# Allocations
# Alloys
# Allscripts
# AllScripts - Hospital Systems (Sunrise)
# Allscripts Canopy
# Allscripts HER
# Allscripts Misys Healthcare Systems
# Allscripts Payerpath
# Allscripts PM
# Allscripts Professional EHR
# Allscripts Professional PM
# Allscripts Sunrise Clinical Manager
# All-Source Intelligence
# Allstar Software Systems Kofax
# ALM
# Almaris E-Learning Systems Financial Accounting Tutor
# ALP
# Alpha Four
# Alpha Generation
# Alpha Software Alpha Five
# AlphaCAM
# AlphaDent
# Alpine
# ALS
# ALSA
# Alstom ESARAD
# Alstom ESATAN
# ALTA Surveys
# Altair Engineering MotionSolve
# AltaPoint Data Systems AltaPoint Dental
# AltaPoint Data Systems AltaPoint Vision
# Alteer Office
# Alteer Premiere
# Altera
# Altera hardware description language AHDL
# Altera MAX
# Altera Quartus
# Altera Quartus II
# Alterations
# Alternative Dispute Resolution
# Alternative Education
# Alternative Energy
# Alternative Fuel Vehicles
# Alternative Fuels
# Alternative Investments
# Alternative Medicine
# Alternative Payments
# Alternative Rock
# Alteryx
# Altia Design
# Altiris
# Altiris Console
# Altium
# Altium Designer
# Alto
# Alto Flute
# Alto Saxophone
# Altova MapForce
# Alua Software Paddock Pro
# Alumina
# Aluminum
# Aluminum Alloys
# Alumni Affairs
# Alumni Relations
# ALV
# ALV Reporting
# ALV Reports
# Alvarion
# Alzheimer&#39;s Care
# Alzheimer&#39;s Disease
# AM Best Data Analytics
# AMA style
# Amadeus
# Amadeus Altea Reservation
# Amadeus GDS
# AMAG
# Amalgamation
# Amateur Photographer
# Amateur Photography
# Amateur Radio
# Amateur Radio Operator
# Amavis
# Amazing Charts
# Amazon Cloud Architect
# Amazon CloudFront
# Amazon Data Pipeline
# Amazon DynamoDB
# Amazon EBS
# Amazon EC2
# Amazon Elastic MapReduce (EMR)
# Amazon Fire
# Amazon IoT Platform
# Amazon Kindle
# Amazon Kinesis
# Amazon Lambda
# Amazon Mechanical Turk
# Amazon RDS
# Amazon S3
# Amazon SimpleDB (SDB)
# Amazon SQS
# Amazon VPC
# Amazon Web Services
# Amazon Web Services (AWS)
# Amazon Web Services CloudFront
# AMB
# AMBA
# AMBA AHB
# Amber Road
# Ambiance
# Ambient Air Monitoring
# Ambient Design ArtRage
# Ambient Intelligence
# Ambient Media
# Ambulance
# Ambulatory
# Ambulatory Care
# Ambulatory Surgery
# AMC
# Amcom AUTOS2000
# AMCs
# AMD64
# Amdocs
# Amdocs Clarify
# American Association of Critical Care Nurses AACN Medicopeia
# American Board of Internal Medicine
# American Cuisine
# American Data Systems PAWS Veterinary Practice Management
# American English
# American Foreign Policy
# American Glazing Software AGS WindowPricer
# American HealthTech Financial
# American History
# American Legalnet eDockets
# American Legalnet Smart Dockets
# American LegalNet USCourtForms
# American Literature
# American Medical Association CodeManager
# American Medical Billing Software PMA
# American National Standards Institute ANSI C
# American Orthodontics Compu-Ceph
# American Orthodontics Photo-Eze
# American Orthotic and Prosthetic Association CodingPro
# American Politics
# American Precision Instruments Regit
# American Printing House for the Blind Learn Keys
# American Printing House for the Blind Talking Typer
# American Riviera Magtax
# American Sign Language
# American Sign Language ASL browser
# American Sign Language Browser
# American Studies
# American Welding Society (AWS)
# AmericanMedicalAssoc(AMA) Data Analytics
# Americans with Disabilities Act
# AMESim
# AMFI
# AMFI Certified
# AMFPHP
# AMG Teleran SalesInSync
# Amharic
# AMHS
# AMI
# Amicus
# Amiga
# Amine Treating
# Amino Acids
# Amipro
# Amira
# Amisys
# Amkai AmkaiCharts
# AMLS
# Ammonia
# Ammonia Refrigeration
# AmoK Translator
# Amortization
# Amortization calculation software
# Amortization loan software
# Amortization Schedules
# AMOS
# Amphibians
# Amphibious Operations
# AMPL
# Amplification
# Amplifiers
# AMPS
# AMQP
# AMR
# AMRT
# AMS REALTIME Projects
# AMS Services AMS 360
# AMS Services AMS Sagitta
# AMS360
# AMSI
# AMTdirect
# Amtec Engineering Tecplot
# Amtech
# AMX
# AMX Programmer
# Anacomp CaseLogistix
# Anadigm Designer2 EDA
# Analog Circuit Design
# Analog Circuits
# Analog Devices VisualDSP++
# Analyse-it
# Analysis
# Analysis and building software
# Analysis and Visualization of Time Sequences AVTS
# Analysis of business problems/needs
# Analysis of Smoke Control Systems ASCOS
# Analyst Briefings
# Analyst Notebook
# Analytical Chemistry
# Analytical Graphics STK Expert Edition
# Analytical Method Validation
# Analytical Skills
# Analytical software
# Analytical Ultracentrifugation
# Analytics
# Analyz
# AnalyzerXL
# Anand Systems ASI FrontDesk
# Anasazi Software Assessment and Treatment Plan Systems
# Anasazi Software Client Data System
# Anatomic pathology software
# ANCA ToolRoom
# ANCC
# Anchors
# Ancient Greek
# Ancient History
# Ancient Philosophy
# Ancillary Benefits
# Ancillary Relief
# Ancillary Revenue
# Ancillary Services
# ANCOVA
# ANDA
# ANDAs
# AndersonBell Abstat
# Andon
# Android
# Android Development
# Android Honeycomb
# Android SDK
# Android Studio
# Android Wear SDK
# Andrology
# AndroMDA
# Anechoic Chamber
# Anemia
# Anesthesia
# Anesthesia machine software
# Anesthesiology
# Angel Card Readings
# Angel Investing
# Angel LMS
# Angel Readings
# Anger Management
# Angiogenesis
# Angiography
# Angioplasty
# Angoss KnowledgeSEEKER
# Angular.js
# AngularJS
# Animal Behavior
# Animal Care
# Animal Feed
# Animal Handling
# Animal Health
# Animal Husbandry
# Animal Intelligence Software Animal Intelligence
# Animal Models
# Animal Nutrition
# Animal Rights
# Animal Science
# Animal Shelter Manager
# Animal Surgery
# Animal Training
# Animal Welfare
# Animal Work
# Animation
# Animation Direction
# Animation Production
# Animation software
# Aninoquisi MesoTRAC
# ANISN dose assessment computer code
# Anisotropic Crystalline Etch Simulation ACES
# Ankle
# Ankylosing Spondylitis
# Anniversaries
# Annotated XML (AXML)
# Annotation
# Announcements
# Annual Budgets
# Annual Campaign
# Annual Fund
# Annual Giving
# Annual Meetings
# Annual Planning
# Annual Reports
# Annual Returns
# Annual Reviews
# Annuities analysis software
# Annuity Sales
# Anodas Software Limited Phoenix
# Anodizing
# Anomaly Detection
# Anomaly Resolution
# ANOVA
# ANPR
# Anritsu Certified
# ANSI
# ANSI C
# ANSI X12
# ANSI Y14.5
# Ansible software
# Ansoft HFSS
# Ansoft Simplorer
# Ansos
# ANSYS
# ANSYS AQWA
# ANSYS ASAS
# ANSYS FLUENT
# ANSYS LS-DYNA
# ANSYS Mechanical
# ANSYS Multiphysics
# Ant
# Antek HealthWare LabDAQ
# Antenna House
# Antenna Measurements
# Antenna Services
# Antennas
# AnthillPro
# Anthropology
# Anthropometric databases
# Anti Money Laundering
# Anti-aging Products
# Antibacterial
# Antibodies
# Anti-Bullying
# Anticoagulation
# Anti-corruption
# Anti-counterfeiting
# Anti-Kickback Statute
# Anti-oppression
# Anti-phishing
# Anti-phishing software
# Anti-piracy
# Antique Furniture
# Antiques
# Anti-spyware software
# Anti-Trojan software
# Antitrust Law
# Antivirus
# Antivirus software
# Anusara Yoga
# Anvil
# Anvil Studio
# ANVISA
# Anxiety Management
# Anycast
# Anylogic
# Anything Goes
# AOC
# AOD
# AODA
# AOG
# AOI
# AOL MapQuest
# Aonix Software Through Pictures
# AOP
# AP ENPS
# AP Style
# APA
# APAC
# Apache
# Apache Ambari
# Apache Anaconda
# Apache Ant
# Apache Avro
# Apache Camel
# Apache Cassandra
# Apache Commons
# Apache Continuum
# Apache Derby
# Apache Flume
# Apache FOP
# Apache Giraph
# Apache Groovy
# Apache Gump
# Apache Hadoop
# Apache Hadoop HANA Integration
# Apache Hbase
# Apache Hive
# Apache HTTP Server
# Apache Ivy
# Apache Jmeter
# Apache Kafka
# Apache Kudu
# Apache Mahout
# Apache Maven
# Apache MRUnit
# Apache Oozie
# Apache Pig
# Apache Ranger
# Apache Software Foundation Flex
# Apache Solr
# Apache Spark
# Apache Sqoop
# Apache Storm
# Apache Struts
# Apache Subversion
# Apache Subversion SVN
# Apache Synapse
# Apache Tiles
# Apache Tomcat
# Apache Tomcat servlet container
# Apache Velocity
# Apache Webserver
# Apache Whirr
# Apache ZooKeeper
# APACS
# Apama
# Apartments
# Apatar
# APB
# APC
# APC UPS
# APDL
# ApE A Plasmid Editor
# Aperture
# Apex Business Software iBenefits
# Apex Business Software iHR
# Apex Data Loader
# Apex IV Assessor
# Apex IV Fee Appraiser
# Apex MobileSketch
# Apex Programming
# Apfloat
# APhA
# Aphasia
# Apheresis
# API 510
# API 570
# API 653
# API 6A
# API Development
# API Healthcare ActiveStaffer
# API manufacturing
# API Navigator
# API Testing
# Apian SurveyPro
# APICS
# APICS Member
# APIs
# APL
# APLAC
# APMP
# APMP Qualified
# APO SNP
# Apogee
# Apollo
# Apollo GDS
# Apollo Photonics APSS
# Apollo Reservation System
# Apologetics
# Apoptosis
# App Designer
# App Developer
# App Software Associations AppTrak.net
# Apparel
# Apparel Sourcing
# APPCA Personal Chef Office
# Appcelerator Titanium
# Appeals
# Appellate Practice
# AppFolio Property Manager
# Apple Aperture
# Apple AppleScript
# Apple AppleWorks
# Apple Certified
# Apple Cocoa
# Apple Compressor
# Apple DrawBerry
# Apple DVD Studio Pro
# Apple Final Cut Express
# Apple Final Cut Pro
# Apple Final Cut Pro X
# Apple Final Cut Studio
# Apple GarageBand
# Apple iBooks Author
# Apple iDVD
# Apple iMovie
# Apple iPhoto
# Apple iWork
# Apple iWork Keynote
# Apple iWork Numbers
# Apple iWork Pages
# Apple iWorks Pages
# Apple Logic Pro
# Apple macOS
# Apple MainStage
# Apple Motion
# Apple Numbers
# Apple Numbers for Mac
# Apple Pages
# Apple Pages for Mac
# Apple QuickTime
# Apple Safari
# Apple Watch
# Apple Xsan
# Applescript
# Appliance Installation
# Appliance Repair
# AppliCad Roof Wizard
# Applicant tracking software
# Applicant Tracking Systems
# Application Architecture
# Application consolidation
# Application Integration
# Application Lifecycle Management
# Application management software
# Application Migrations
# Application Packaging
# Application Security
# Application server software
# Application Software SHEAR
# Application Virtualization
# Application-specific integrated circuit ASIC logic synthesis software
# Applied Behavior Analysis
# Applied Biosystems GeneMapper
# Applied Computer Systems JOBPOWER
# Applied Flow Technology AFT Arrow
# Applied Flow Technology AFT Fathom
# Applied Imagery Quick Terrain Modeler
# Applied Kinesiology
# Applied Linguistics
# Applied Mathematics
# Applied Production ProFab
# Applied Production ProFold
# Applied Search Technology CADFind
# Applied Software Technologies Asset Maintenance and Materials Management System
# Applied Structural Drying
# Applied Systems Associates aSa Rebar
# Applied Systems The Agency Manager
# Applied Systems Vision
# Appligent Citation FDFMerge
# Appointment Scheduling
# Appointment scheduling software
# Appointment Search
# Appointment-Plus
# AppointmentQuest Online Appointment Manager
# AppointmentQuest Online Appointment Scheduler
# Appraisal software
# Appraisals
# Approximation Algorithms
# AppScan Source
# Apraxia
# Aprimo
# Aprimo Marketing
# Aprons
# APS
# APT
# Aptamers
# Aptana
# Aptean Made2Manage
# Aptean Onyx CRM
# Aptech Systems GAUSS
# Apteryx Imaging Suite
# Aptify
# Apttus Testing
# APV
# APX
# Aqsis Renderer
# AquaSoft Farm Manager
# Aquatic Ecology
# Aquatic Plant Information Retrieval System APIRS
# Aquatic Toxicology
# Aquifer test software
# Arabic
# Arab-Israeli Conflict
# Aramaic
# ARAS
# Araxis Merge
# ArbelSoft TailorMax
# Arbita OnePost
# Arbita OneWorld
# Arbitrage
# Arbitration
# Arbitron
# Arbor
# Arbor Image Draftsman
# Arboriculture
# Arbortext
# Arbortext Epic Editor
# Arbutus Analyzer
# ARC
# Arc Flash
# ARC Logics Sword
# Arc Second PocketCAD
# Arc Welding
# ArcGIS
# Archaeological Illustration
# Archeological Sites Management Information System ASMIS
# Archer Compliance Management
# ArchiCAD
# Architect
# Architectural Acoustics
# Architectural Design
# Architectural Details
# Architectural Drawings
# Architectural Energy Corporation ENFORMA Building Diagnostics
# Architectural Energy Corporation REM/Rate
# Architectural Energy Corporation VisualDOE
# Architectural Glass
# Architectural History
# Architectural Illustration
# Architectural Lighting
# Architecture
# Architecture description language ADL
# Archival databases
# ArchiveGrid
# Archives
# Archives Wiki
# Archivists' Toolkit
# Archon
# Archtics Ticketing System
# Arcline ArcFreight
# ARCOM Masterspec
# ArcSight App Security Monitor (AppSM)
# ArcSight Enterprise Threat and Risk Management
# ArcSight: SmartConnector Foundations
# Ardexus Mode
# Ardexus TASC
# ARDMS
# Ardome
# Arduino
# Area Classification
# Area Rug Cleaning
# Area Rugs
# Area Studies
# Arena Health Systems Phys-X
# Arena Simulation Software
# Arenas
# ArenaSoft Estimating
# ARES
# ARES Corporation PRISM Project Estimator
# ARFF
# ARfit
# Argentine Tango
# Argo
# Argos Software ABECAS Insight
# Argos Software ABECAS Insight Freight Management System FMS (accounting feature)
# Argos Software ABECAS Insight Freight Management System FMS (calendar and scheduling feature)
# Argos Software ABECAS Insight WMS
# Argosy Legal Systems Power Closer
# ArgoUML
# Argumentation
# Arguments
# Argus Modeling
# Argus Monitoring Software
# Argus ONE Open Numerical Environments
# Argus Perceptual Mapper
# Argus Safety
# ARIA
# Arianna
# Ariba
# Ariba Direct Procurement
# Ariba Spend Management Suite
# Aries
# ARIMA
# ARINC 429
# ARINC 653
# ARIS
# Aris Global Register
# ARISg
# Arista
# Arithmetic
# ARK Software Ark Shelter Software
# Arkenstone Atlas Speaks
# Arkitektia Flight Itinerary
# ARM
# ARM Assembly
# ARM Cortex-M
# ARMA
# Armand Morin MultiTrack Generator
# Armchair Machinist software
# Armenian
# ARMON Technologies XLActuary
# Armor
# Arms Control
# Army
# Army Food Management Information System
# Arobas Music Guitar Pro
# Aromatherapy
# Aromatics
# ARP
# ARPA
# Arpege Music Pizzicato
# Arping
# ARRA
# Arranging
# Array Formulas
# Array Processing
# Arri
# Arri Alexa
# Arriflex
# Arrival Departure Information System ADIS
# Arrow Electronics N/Compass
# ARRT
# Arsenic
# ARSoftware WinSMAC
# Arson
# Art
# Art Direction
# Art Education
# Art Exhibitions
# Art Gallery
# Art Glass
# Art Handling
# Art History
# Art Nouveau
# Art Song
# Article Rewriting
# Article Submission
# Articles
# ArticSoft FileAssurity
# Articulate Rapid E-Learning Studio
# Articulate Storyline
# Articulate Suite
# Artifice DesignWorkshop
# Artificial Intelligence
# Artificial intelligence software
# Artificial Learning
# Artificial Neural Networks
# Artisan Studio
# Artistic Abilities
# Artistic Eye
# Arts & Letters Express
# Arts &amp; Crafts
# Arts / Crafts
# Arts Administration
# Artsco OrthoPro Complete
# ArtScope.net eArtist
# Artsystems Collections
# Aruba Networks AirWave
# Aruba Wireless
# AS Software AS-OBGYN
# AS/400 Database
# AS400 / iSeries
# Asana
# ASAP
# Asbestos
# Asbestos Litigation
# Asbestos Removal
# ASCE
# ASCE 7
# Ascend
# Ascend Property Assessment
# Ascensio Systems TeamLab
# Ascent Capture
# Ascentis Employee Self-Service
# Ascentis HR
# ASCII
# ASCP
# ASDM
# ASE Certified
# ASEAN
# Aseptic Processing
# Aseptic Technique
# ASG Technologies ASG-Zeke
# Ash
# Ashiatsu
# Ashkon Translation Pad
# Ashlar-Vellum Cobalt
# Ashlar-Vellum Graphite
# Ashley Software Writer's Blocks
# ASHRAE
# Ashtanga
# ASI
# ASI Client Acquisition Solution
# ASI DATAMYTE GageMetrics
# ASI DATAMYTE QDA
# ASI FrontDesk
# ASI Point of Sale
# Asia Business Development
# Asian American Studies
# Asian Art
# Asian Business
# Asian Cuisine
# Asian Culture
# Asian Markets
# Asian Politics
# Asian Studies
# ASIC
# ASID
# ASIDATAMYTE DataMetrics
# Asigra
# ASIS
# ASK MANMAN
# Askia Analyse
# Askia Design
# Askia Face
# Askia Vista
# Askia Voice
# Askia Web
# askSam Systems SurfSaver
# ASL HR Director
# ASME
# ASME Y14.5
# ASN.1
# ASNT
# ASON
# ASP
# ASP Baton
# ASP.NET
# ASP.NET AJAX
# ASP.NET MVC
# ASP.NET Web API
# ASPE
# Aspect ACD
# Aspect Loss Prevention Aspect EliteLP
# AspectJ
# Aspen
# Aspen Custom Modeler
# Aspen Dynamics
# Aspen Graphics
# Aspen HYSYS
# Aspen Plus
# Aspen Research Group Aspen Graphics
# AspenTech Aspen InfoPlus
# AspenTech aspenONE for Chemicals
# AspenTech HYSYS
# Aspera
# Aspera SmartTrack Operations
# Asperger&#39;s
# Asphalt
# Asphalt Paving
# Asphalt Shingles
# Aspose
# Asprova
# ASPX
# Aspyra CyberLAB
# Aspyra CyberPATH
# ASR Software LWC-Plus
# ASR Software Taper-Plus
# ASR Software TopView LE
# ASR Software TopView ME
# ASRS
# Assay Development
# Assembla
# Assembler
# Assembly
# Assembly Language
# Assembly line balancing software
# Assembly Lines
# Assessment Center
# Assessment software
# Assessment Systems Corporation XCALIBRE
# Asset Allocation
# Asset allocation software
# Asset Based Lending
# Asset Central Foundation (ACF)
# ASSET JTAG ScanWorks
# Asset Life Cycle Management
# Asset Management
# Asset management administration software
# Asset management software
# Asset Protection
# Assisi Software Assisi Compiler
# Assisi Software Assisi Inventory
# Assisi Software Assisi Manager
# Assisi Software Assisi Resource
# Assisi Software Compiler
# Assisi Software Forest
# Assisi Software Forest Inventory
# Assistant Directing
# Assistant Software for Antimicrobial Susceptibility Interpretation ASASI
# Assisted model building with energy refinement AMBER
# Assisting Others
# Assistive Listening Devices
# Associated Press style
# Association for Computing Machinery Digital Library
# Association Rules
# Assortment
# Assurance
# Assured Software JPP
# AssurX CATSWeb
# AssurX Financial Services Compliance Management System
# AST Staff Matrix
# Asta Powerproject
# Astaro
# Aster Data nCluster
# Asterisk
# Asterisk PBX
# Asterix
# Asthma
# ASTM
# ASTM standards
# Astro
# Astrobiology
# Astrodynamics
# Astrology
# Astronautics
# Astronomical Image Processing for Windows AIP4WIN
# Astronomical Image Processing System AIPS
# Astronomical information processing system AIPS++
# Astronomy
# Astrophysics
# Astute
# Astute Solutions PowerCenter
# Asure Software HCM
# ASW
# Asylum
# Asymmetric Catalysis
# Asymmetric Synthesis
# Asymmetric Warfare
# Async
# A-Systems Jobview
# At Risk
# A-T Solutions Easy Street Draw
# At Your Service Software At Your Service Repair
# At Your Service Software CostGuard
# AT&T Troff
# ATA
# ATCA
# ATD protocol
# ATDD
# ATEX
# ATG
# ATG Commerce
# ATG CSC
# ATG Dynamo
# ATG Search
# Athena
# Athena Software Penelope Case Management
# athenahealth athenaCollector
# Atherosclerosis
# Athlete Development
# Athlete Marketing
# Athlete Representation
# Athletic Administration
# Athletic Apparel
# Athletic Facilities
# Athletic Fields
# Athletic Footwear
# Athletic Performance
# Athletic Recruiting
# Athletic Training
# Athletics
# ATI Vision
# ATL
# ATL COM
# Atlas
# Atlas AdManager
# Atlas Business Solutions Staff Files
# Atlas Construction Business Forms
# Atlas Media Console
# Atlas Search
# Atlas.ti
# Atlassian Bamboo
# Atlassian Confluence
# Atlassian HipChat
# Atlassian JIRA
# ATLS
# ATM Networks
# ATMega
# Atmel
# Atmel AVR
# Atmospheric Chemistry
# Atmospheric Modeling
# Atmospheric Physics
# Atmospheric Science
# ATMs
# ATMS StockTrack PLUS
# ATO
# Atoll
# Atoll GeoCAD
# Atom
# Atomic Absorption
# Atomic Layer Deposition
# Atomic Physics
# Atomic Spectroscopy
# Atomix Productions VirtualDJ
# Atopic Dermatitis
# ATP
# ATPG
# ATR
# ATR-FTIR
# Atria smoke management engineering tools ASMET
# Atrial Fibrillation
# Atrion Intelligent Authoring
# Atrium Orchestrator
# ATRP
# ATSC
# AtStaff Physician Scheduler
# Attachment Parenting
# Attachment Theory
# AtTask
# Attendance Management
# Attendance tracking software
# Attendee Registration
# Atterbury Consultants SuperAce
# Atterbury Consultants SuperACE/FLIPS
# Attic Access Ladders
# Attitude POS itive AccuPOS Retail
# Attorney
# Attorneys
# Attraction Marketing
# Attraction Strategies
# Attribution
# Attribution Modeling
# Attrition
# ATV
# ATX Total Accounting Office
# ATX Total Engagement Office
# ATX Total Tax Office
# Auburn Software Debit Square
# Auction Management
# Auctioneers
# Auctions
# Audacity
# Audience Measurement
# Audience Segmentation
# AudienceView Ticketing
# Audio Amplifiers
# Audio calibration software
# Audio Chaos Soundscape Generator
# Audio Editing
# Audio editing software
# Audio Engineering
# Audio Mixing
# Audio Post Production
# Audio Production
# Audio Services
# Audio Typing
# Audion Laboratories VoxPro
# AudioScribe SpeechCAT
# Audit
# Audit management software
# Audit planning and control environment software
# Audit2 AdaptiveGRC
# AUDIT-C
# Auditing
# Auditing software
# Audits of Employee Benefit Plans
# AuditWare
# AuditWare CaseWare Examiner
# Audiveris
# Auger
# Auger electron spectroscopy
# Augmentative Communication
# Augmented Reality
# Augmint
# August Systems Visit Wizard
# AUP
# Aura
# Aural Rehabilitation
# Auricular Acupuncture
# Aurora Browse
# Aurora FoodPro
# Austin Logistics CallSelect
# Austin Logistics CallTech
# Austin Logistics Valeo
# Australasia
# Australian Equities
# Australian Tax
# Australian Taxation
# Authoria Adviser
# Author-it
# Autism Spectrum Disorders
# AUTO
# Auto Body
# Auto Detailing
# Auto Glass
# Auto Racing
# Auto3DEM
# AutoCAD
# AutoCAD Architecture
# AutoCAD Civil 3D
# AutoCAD Mechanical
# AutoClaims Direct DirectLink
# Autocoders
# AutoCrit Editing Wizard
# Autodesk 3D Studio Design
# Autodesk 3d Studio Viz
# Autodesk 3ds Max
# Autodesk 3ds Max Design
# Autodesk Algor Simulation
# Autodesk Alias Automotive
# Autodesk Alias Design
# Autodesk Alias Surface
# Autodesk AliasStudio
# Autodesk Architectural Desktop
# Autodesk Architectural Studio
# Autodesk AutoCAD
# Autodesk AutoCAD Blue Sky
# Autodesk AutoCAD Civil 3D
# Autodesk AutoCAD Design Suite
# Autodesk AutoCAD Land Desktop
# Autodesk AutoCAD LT
# Autodesk AutoCAD MAP3D
# Autodesk AutoCAD Mechanical
# Autodesk Building Systems
# Autodesk Buzzsaw
# Autodesk CAiCE Visual Transportation
# Autodesk Combustion
# Autodesk ECOTECT
# Autodesk Ecotect Analysis
# Autodesk Fusion 360
# Autodesk HSMWorks
# Autodesk Inventor
# Autodesk Land Desktop
# Autodesk MapGuide
# Autodesk Maya
# Autodesk Maya for Design Visualization
# Autodesk Mechanical
# Autodesk MotionBuilder
# Autodesk Mudbox
# Autodesk PartMaker
# Autodesk PowerMill
# Autodesk PowerShape
# Autodesk Revit
# Autodesk Revit Architecture
# Autodesk Scaleform
# Autodesk SketchBook Pro
# Autodesk Smoke
# Autodesk Softdesk
# Autodesk SoftImage
# Autodesk Software
# Autodesk Topobase
# Autodesk Vault
# Autodesk VIZ
# Autodesk World
# AutoDesSys form Z
# AutoHotkey
# Automate the Schools ATS
# Automated audit trail analysis software
# Automated auditors fraud detector software
# Automated billing software
# Automated Biometric Identification System ABIS
# Automated circulation systems
# Automated clinical information systems
# Automated commercial environment software ACE
# Automated Data Collection System ADCS
# Automated document generation software
# Automated equipment identification AEI software
# Automated expense reporting system software
# Automated financial software
# Automated Geospatial Watershed Assessment AGWA
# Automated information system software
# Automated installation software
# Automated inventory software
# Automated Manifest System AMS
# Automated manifest system software
# Automated material handling software
# Automated media tracking software
# Automated National Catalog System ANCS
# Automated Neuropsychological Metric Assessments Battery
# Automated Package Processing System APPS
# Automated payroll software
# Automated permit system software
# Automated purchase order software
# Automated radar terminal systems ARTS
# Automated system for customs data ASYCUDA
# Automated systems software
# Automated Targeting System ATS
# Automated tax system software
# Automated timekeeping software
# Automated underwriting software
# Automated Underwriting Systems
# Automatic call distribution software
# Automatic Data Processing AdvancedMD EHR
# Automatic Data Processing Autosource
# Automatic Data Processing Claims Manager & Dispatch
# Automatic Data Processing Estimating
# Automatic Data Processing PC payroll for windows PCPW
# Automatic Data Processing ProxyEdge
# Automatic dynamic incremental nonlinear analysis ADINA
# Automatic Forecasting Systems Autobox
# Automatic routing software
# Automatic test program generation ATPG
# Automation
# Automation Centre Personnel Tracker
# Automation Centre TrackerSuite.Net
# Automation Counselors municiPAL
# Automation Studio
# Automic
# Automobile
# Automobile Accidents
# Automobile Liability
# Automotive
# Automotive Aftermarket
# Automotive and Accounting Software by R*KOM Invoice Writer
# Automotive Electronics
# Automotive Engineering
# Automotive Locksmithing
# Automotive Parts
# Automotive Repair
# Autonomous Vehicles
# Autonomy IDOL
# Autonomy iManage WorkSite
# Autopilot software
# Autopsy information databases
# AutoQ3D
# AutoQuant AutoDeblur
# Autotask
# AutoTester
# AutoZone ALLDATA
# AUV
# Auxillium West HRnetSource
# Avaaz Innovations AphasiaMate
# Avaaz Innovations Computerized Speech Research Environment CSRE
# Avaaz Innovations Interactive Voice Analysis System IVANS
# Availability
# Availability prediction modeling software
# Available Safe Egress Time ASET
# Avalanche
# Avalara AvaTax ST
# Avaloq
# Avante
# Avant-garde
# Avantis
# Avast
# Avatars
# Avature
# Avaya AES
# Avaya ASA
# Avaya Aura
# Avaya Communication Manager
# Avaya Identity Engines
# Avaya IP Telephony
# Avaya Technologies
# AVC
# AVCHD
# Avenista Table Reservations
# Avenue
# Aveva Group Plant Design Management System PDMS
# AVEVA PDMS
# AVG
# Aviation
# Aviation Electronics
# Aviation Law
# Aviation Regulations
# Aviation Security
# Avid
# Avid Audio Pro Tools
# Avid Digidesign Pro Tools
# Avid DS Nitris
# Avid iNEWS
# Avid Media Composer
# Avid Newscutter
# Avid Pro Tools
# Avid Symphony
# Avid Technology
# Avid Technology 2D Character Generator
# Avid Technology iNEWS
# Avid Technology Media Composer
# Avid Technology NewsCutter
# Avid Technology Pinnacle Studio
# Avid Technology Pro Tools
# Avid Technology Sibelius
# Avid Xpress
# Avidian Technologies Prophet
# Avimark
# Avionics
# Avionics Integration
# Avionics system testing software
# Avis Fits Viewer
# AVL
# AVL AVL CRUISE
# AVL Boost
# AVO
# AVR
# AVR Studio 4
# Avreo Radiology Workflow Solutions
# Avro
# AVS
# AVS Scripting
# AVST
# Award Ceremonies
# Award Submissions
# Award Winner
# Award-winning writer
# Awareness Raising
# Aweber
# Awesomeness
# AWIPS
# Awk
# Awnings
# AWR
# AWR Microwave Office
# AWS AR & VR
# AWS Business Productivity
# AWS Connect
# AWS CWI
# AWS Data Pipeline
# AWS Developer Tools
# AWS Redshift
# AWStats
# AWT
# AWWA
# AXE
# Axentis Compliance Management
# AXI
# Axioma
# Axios Systems assyst
# Axis
# Axis2
# Axistive BigShot Screen Magnifier
# Axles
# Axonwave Fraud and Abuse Management System
# Axure
# Axure RP
# Axway API Management
# Axway eSubmissions
# Axway Managed File Transfer
# Axxya Systems Nutritionist Pro
# Axys
# Aya Associates Comp-U-Floor
# Ayurveda
# Azalea Health Azalea EHR
# Azemus FS
# Azerbaijani
# Aztec
# AzTechSoft GPS2CAD
# Azure
# Azure Synapse Analytics
# AZZ CardFile
# B Sharp Technologies B Care
# B&I Computer Consultants Childcare Sage
# B&W Port Scanner
# Baan
# Baan ERP
# Babcock Winx Pro
# BABOK
# Baby Blessings
# Baby Products
# Baby Showers
# Babylon Online Translator
# Babysitting
# Back Office
# Back Pain
# backbone.js
# Back-end Development
# Backend Development Services
# Background Art
# Background checking software
# Background Checks
# Backhaul
# Backing Vocals
# Backpacking
# Backtrack
# Backup - Design and Implementation
# Backup and archival software
# Backup Exec
# Backup Solutions
# BACnet
# Bacterial Cell Culture
# Bacterial Culture
# Bacterial Transformation
# Bacteriology
# Bad Faith
# Bada
# Badboy
# Badges
# BADIs
# Badminton
# BAE Systems SOCET GXP
# BAE Systems SOCET SET
# Baggage Handling Systems
# Bagging
# Bagpipes
# Bags
# Bahasa Indonesia
# Bahasa Malaysia
# Baidu
# Bail Bonds
# Bail Enforcement
# Bailey
# Baker Hill
# Bakery
# Baking
# BAL
# Balance
# Balance Sheet
# Balance Sheet Review
# Balanced Literacy
# Balanced Scorecard
# Balayage
# Baldrige Examiner
# Balkans
# Ballet
# Balloon Artist
# Ballot Initiatives
# Ballroom Dance
# Balsamiq
# Balsamiq Studios Balsamiq Mockups
# Balustrading
# BAM
# Bamboo
# Bamboo Flooring
# Bancassurance
# Band Saw
# Bands
# Bank Reconciliation
# Bank Secrecy Act
# Bankers Systems Rembrandt Lending System
# Banking
# Banking Application Spec & Select
# Banking Law
# Banking Relationships
# Banking Setup
# Bank-owned Properties
# Bankruptcy
# Banner Ads
# Banner Design
# Banners
# Banquet Operations
# Banquets
# BAPI
# Bar
# Bar/Bat Mitzvahs
# Barbering
# Barcode
# Barcode labeling software
# Barcode reader software
# Barcode Scanners
# Barcode software
# Barcode Technology
# BarControl Enterprise Manager iBEM
# Bare Bones Software BBEdit
# Bargaining
# Bargaining Power
# Barge
# Bariatric Surgery
# Bariatrics
# Barista
# Barista Training
# Baritone
# Baron Services FasTrac
# Baron Volumetric Imaging and Processing of Integrated Radar VIPIR
# Baroque
# Barra Aegis
# Barracuda Spam Filter
# Barracuda Spam Firewall
# Barrel Racing
# Barrington Software CookenPro
# Barrington Software CookenPro Commercial
# Bartending
# Barter
# Base Metals
# Base SAS Certified
# Baseball
# Basecamp
# Basel II
# Basel III
# Basements
# Bash
# Bashen EEOFedSoft
# Bashen EEOSoft
# Bashen LinkLine
# Basic HTML
# Basic Local Alignment Search Tool BLAST
# Basic Music Composer
# Basis BBx VisualPRO/5
# Basketball
# Basketball Coaching
# Basque
# Bass
# Bass Fishing
# Bass Guitar
# Basware
# Batch Files
# Batch Processing
# Batch Programming
# Batch Records
# Batch Release
# Bathing
# Bathroom
# Bathroom Remodeling
# Bathroom Vanities
# Bathrooms
# Bathymetry
# Batik
# Batteries
# Battery Charger
# Battery Management Systems
# BAU
# Bauxite
# Bayesian inference
# Bayesian methods
# Bayesian networks
# Bayesian statistics
# Bazaar
# BBEdit
# BBP
# BBx
# BCA Protein Assay
# BCCORP Burkitt W5
# BCCORP W5 for Adjusters
# BCL Landview Systems WinCrop
# BCLS
# BCM
# BCMS
# BCNE
# BCS Woodlands Software The Logger Tracker
# BCS Woodlands Software Woodlands Tracker
# BCS Woodlands Systems The Logger Tracker
# BD Biosciences CellQuest
# BD Biosciences CloneCyt
# BDC
# BDC programming
# BDCs
# BDD
# BDMS
# Be Your Own Boss
# BEA Tuxedo
# Beach Homes
# Beaches
# Beacon
# Beading
# Beads
# Beam analysis software
# BeamChek
# Beamforming
# Beans
# Bearings
# Beat Making
# Beat Reporting
# Beatboxing
# Beats
# Beauty Industry
# Beaver Creek Software The THERAPIST
# Bechtel Software SETROUTE
# Beck Anxiety Inventory
# Beck Depression Inventory
# Becrypt
# Bed Bugs
# Bed Management
# Bed Management Suite
# Bed Sheets
# Bedding
# Bedroom Furniture
# Bedrooms
# Beds
# Bedside Manner
# Bedspreads
# Beef
# Beef Cattle
# Beehive
# Beekeeping
# Beeline Learning Management System LMS
# Beer
# Bees
# Beginner's all-purpose symbolic instruction code BASIC
# BehavePlus
# Behavior Based Safety
# Behavior Change
# Behavior Management
# Behavior Modification
# Behavioral Assessment and Research System BARS
# Behavioral Finance
# Behavioral Health
# Behavioral Intervention
# Behavioral Interviewing
# Behavioral Neuroscience
# Behavioral Problems
# Behavioral Science
# Behavioral Segmentation
# Behavioral Targeting
# Behavioural Change
# Behind the Scenes
# Beige Bag Software B2 Spice
# Beilstein
# Belarusian
# Bella FSM Auto Detailing Service Software
# Belly Dance
# Belmar & Associates Mortware
# Below the Line Advertising
# Belting
# BEM
# BEMAS PayDirect
# Ben Meadows Yeoman Expedition
# Benaissance COBRApoint
# BenAssist
# Benchmark Systems Benchmark Clinical EHR
# Benchmarking
# Benchmarking (Market Salary Data)
# Benefit Plan Systems Corporation The Plan Administrator
# Benefit Software Fringe Facts
# BenefitFocus HR in Touch
# Benefits Administration
# Benefits Design
# Benefits Management
# Benefits Negotiation
# Benefits Realisation
# Benefits Technology Group SalesLogix
# BeneLink Connect
# Benelogic
# Benetech PRA
# BeneXL Technologies Pension Administration System
# Benfield ReMetrica
# Bengali
# Bentley
# Bentley AutoPLANT
# Bentley GeoPak Bridge
# Bentley GEOPAK Civil Engineering Suite
# Bentley Haestad Methods CivilStorm
# Bentley I/RAS B
# Bentley InRoads Site
# Bentley InRoads Suite
# Bentley MicroStation
# Bentley Navigator
# Bentley PlantSpace SupportModeler
# Bentley ProjectWise
# Bentley SewerCAD
# Bentley StormCAD
# Bentley Systems AutoPIPE
# Bentley Systems gINT
# ...
# Wakeboarding
# Walking Tours
# Walkthroughs
# Walkways
# Wall Decor
# Wall Street
# Wallcoverings
# Wallets
# Walling Info Systems Recruiting Wizard
# Wallingford Software InfoSewer
# Wallingford Software InfoWater
# Wallingford Software InfoWorks CS
# Wallingford Software InfoWorks WS
# Wallpaper
# Walls
# Wal-Mart
# Walmart Retail Link
# Waltz
# WAM
# WAM software
# WAMP
# WAN
# WAN Optimisation
# WAP
# WAP Gateway
# WAP Push
# Ward Systems Group GeneHunter
# Ward Systems Group NeuralShell Predictor
# Ward Systems Group NeuroShell Trader
# Wardrobe
# Wardrobe Analysis
# Wardrobing
# Warehouse Automation
# Warehouse Control
# Warehouse Management
# Warehouse management system WMS
# Warehousing
# Warm Calling
# Warrants
# Warranty
# WASP
# Waste
# Waste Disposal
# Waste Heat Recovery
# Waste Management
# Waste management software
# Waste Reduction
# Waste to Energy
# Waste Treatment
# Waste Water Treatment Plants
# Wastewater expert control systems
# Wastewater Treatment
# Wastewater Treatment Design
# Watches
# WatchKit
# WatchWare Repair Shop
# Water
# Water &amp; Wastewater Design
# Water Conservation
# Water Damage
# Water Damage Restoration
# Water Distribution
# Water Engineering
# Water Erosion Prediction Project WEPP
# Water Features
# Water flow modeling software
# Water Management
# Water Pumps
# Water Quality
# Water Resources
# Water resources databases
# Water Sampling
# Water Sensitive Urban Design
# Water Soil and Hydro-Environmental Decision Support System WATERSHEDSS
# Water Supply
# Water surface pressure gradient WSPG software
# Water Tanks
# Water Treatment
# Watercolor
# Watercolor Illustration
# Waterfall
# Waterfront
# WaterFurnace International Ground Loop Design PREMIER
# Waterloo Hydrogeologic AquaChem
# Waterloo Hydrogeologic AquiferTest Pro
# Waterloo Hydrogeologic FlowPath II
# Waterloo Hydrogeologic RBC Tier 2 Analyzer
# Waterloo Hydrogeologic TACTIC
# Waterproofing
# Waters eLab Notebook
# Waters Empower 2
# Waters Empower Chromatography Data Software
# Waters MassLynx
# Waters Millennium32
# Waters Q-DIS/QM LIMS
# Watershed Management
# Watershed modeling system WMS software
# Watir
# Watson Wyatt CompQuest On-Line
# Watson Wyatt Global Grading System
# Watson Wyatt Reward
# Watter Hammer Software Hytran
# Wave Energy
# Wave Propagation
# Wave Solder
# Waveburner
# Waveform Generators
# Wavefunction Spartan
# Wavefunction Titan
# Waveguide
# Wavelab
# Wavelength
# Wavelets
# WaveMetrics IGOR Pro
# WavePad
# Waves Plug-ins
# WAWF
# Wax
# Wax Carving
# Waxing
# Wayfinding
# WBEM
# WBS
# WBS Goplan
# WBT Systems TopClass
# WBTs
# WCAG
# WCB
# WCCP
# WCDMA
# WCF
# WCF Services
# WCS
# WCSF
# WDF
# WDK
# WDM
# WDS
# Wealth
# Wealth Accumulation
# Wealth Management
# Wealth Management Services
# Wealth Preservation
# Wealth Preservation Planning
# Wealth Transfer
# WealthCounsel WealthDocs
# WealthEngine Findwealth
# WealthTec AllocationPro
# WealthTec Foundations
# WealthTec WealthMaster
# Weapon Systems
# Weapons
# Weapons &amp; Tactics Instruction
# Weapons Handling
# Weapons of Mass Destruction
# Weapons Training
# Weather
# Weather Derivatives
# Weather Forecasting
# Weather Radar
# Weaving
# Web 2.0
# Web Analytics
# Web Application Security
# Web Applications
# Web Box Activity Tracing System WebBATS
# Web broswer software
# Web browser software
# Web Caching
# Web conferencing software
# Web Content
# Web Content Management
# Web content management system CMS software
# Web Crawling
# Web Design
# Web design software
# Web Development
# Web Editing
# Web editing software
# Web Hosting
# Web Information Solutions Pocket Informant
# Web Mapping
# Web Navigation
# Web page creation and editing software
# Web page design and editing software
# Web page design software
# Web Pages
# Web Project Management
# Web Savvy
# Web Scrapbook
# Web Scraping
# Web Search
# Web Security
# Web server software
# Web service definition language WDSL
# Web Services
# Web Services API
# Web Site Production
# Web Testing
# Web Typography
# Web Video
# web2project
# Web-administered databases
# Web-based dispatch software
# Web-based information systems
# Web-based trading systems
# WebClarity Software BookWhere
# WebCT
# Web-Est
# WebEx Sales Center
# WebEx WebOffice
# WebFOCUS
# Webinar software
# WebLogic
# Webmaster Services
# webMethods
# WebOS
# WebPathLab
# Websense Data Loss Prevention
# Website Building
# Website creation software
# Website Design
# Website Development
# Website development software
# Website Localization
# Website Management
# Website management software
# Website Merchandising
# Website Testing
# Website Updating
# WebSphere
# WebSphere Application Server
# WebSphere ESB
# WebSphere Message Broker
# WebSphere Portal
# WebTrends Analytics
# Webtrends software
# Wedding Albums
# Wedding Bands
# Wedding Cakes
# Wedding Coordinating
# Wedding DJ
# Wedding Favours
# Wedding Gowns
# Wedding Industry
# Wedding Management
# Wedding Photography
# Wedding Photojournalism
# Wedding Planning
# Wedding Videos
# Weddings
# Weebly
# Weed Control
# WEEE
# Weibull Analysis
# Weight Gain
# Weight Loss Coaching
# Weight Management
# Weight Training
# Weighting
# Weightlifting
# Weka
# Welding
# Welding Inspection
# Welford Chart Notes
# Well Control
# Well Flow Dynamics Wellflow
# Well Intervention
# Well Logging
# Well logging software
# Well Stimulation
# Well Testing
# Wellbeing
# Wellness
# Wellness Coaching
# Welsh
# WEP
# WERS
# WESB
# West Africa
# West Coast Swing
# Westbrook Fortis
# Western analysis
# Western Blotting
# Western Cuisine
# Western Engravers Supply Vision EXPERT
# Western Europe
# Westlaw
# Westlaw Real Property Deed Images
# Wet Chemical Etching
# Wet Chemistry
# Wet Lab
# Wetland Restoration
# Wetland Science
# Wetlands
# WFA
# WFC
# WFL
# WFO
# WFS
# WGA
# WH Software InstaCode
# WH Software MasterKey
# What-if Analysis
# WhatsApp
# WhatsUp
# WHE Term-PAK
# Wheat
# Wheatworks Real Estate Calculator Suite
# Wheel Throwing
# Wheelchairs
# Wheels
# WheelShop Automation.com Wheel Shop Management Suite
# Wherescape Red
# WHIMS
# Whiplash
# Whisky
# Whistleblower
# Whistling
# White Belt
# White Box
# White Box Testing
# White Clarke North America Credit Adjudication and Lending Management
# White Collar Criminal Defense
# White Glove
# White Goods
# White Hat
# White Label
# White Papers
# Whitebirch Software Projected Financials
# Whiteboarding
# Whitesmoke
# Whitewater Kayaking
# Whittle
# WhizLabs
# WHMCS
# WHMIS
# Whole Brain Thinking
# Whole Foods
# Whole House Audio
# Whole House Renovations
# Whole Life
# Whole Life Costing
# Wholesale
# Wholesale Banking
# Wholesale Lending
# Wholesale Operations
# Wholesale Purchasing
# Wholesale Real Estate
# WHONET
# WIA
# WIC
# WiCAM PN4000
# Wicket
# Wicklander-Zulawski Interview &amp; Interrogation
# Wide area monitoring system WAMS software
# Wide area network WAN optimization software
# Wide area network WAN software
# Wide area remote control system software
# Wide Area Workflow WAWF system
# Wide Format Printing
# Wide Orbit
# Wideband
# Widening Participation
# WideOrbit
# Widgets
# Widisoft WIDI Recognition System
# Widows
# WIF
# WiFi
# Wig Making
# Wigs
# Wii
# WIKI
# Wiki Development
# Wiki Markup
# Wiki software
# Wikimedia
# Wikipedia
# Wikis
# Wikispaces
# Wilcomp Software RenWeb
# Wilcox Associates PC-DMIS
# Wilcox Associates PC-DMIS Inspection Planner
# Wilderness
# Wilderness EMT
# Wilderness First Aid
# Wilderness First Aid Certified
# Wilderness First Responder
# Wilderness Medicine
# Wildfire
# Wildland Fire
# Wildland Fire Assessment System WFAS
# Wildland Firefighting
# Wildlife
# Wildlife Art
# Wildlife Biology
# Wildlife Conservation
# Wildlife Management
# Wildlife Photography
# Wildlife Rehabilitation
# WildPackets OmniPeek Network Analyzer
# Wilhelm Publishing Threshold
# Willoughby Associates MIMSY XG
# Wills
# Wilson's Computer Applications RealEasy Appraisals
# Wilson's Computer Applications RealEasy Photos Plus
# Wily Introscope
# WiMAX
# Wimba
# Win CE
# Win CVS
# Win32 API
# WinBUGS
# Winchester Ammunition Ballistics Calculator
# WinCity Custom Software WinCity Massage SOAP Notes
# WinCross
# Wind
# Wind Energy
# Wind flow modeling software
# Wind Mitigation
# Wind River Systems C/C++ Compiler Suite
# Wind River Systems VxWorks
# Wind River VxWorks
# Wind Tunnel
# Wind Tunnel Testing
# Wind Turbines
# Windent OMS
# Windent SQL
# Window Cleaning
# Window Coverings
# Window Displays
# Window Dressing
# Window Treatments
# WindowBook Postal Package Partner
# Windows
# Windows 7
# Windows 7 Migration
# Windows 8
# Windows API
# Windows Azure
# Windows Batch
# Windows CE
# Windows Desktop
# Windows Domain
# Windows Embedded
# Windows Embedded Compact
# Windows kernel debuggers
# Windows kernel programming
# Windows Live Movie Maker
# Windows Media Encoder
# Windows Media Player
# Windows Media Services
# Windows Mobile
# Windows Movie Maker
# Windows Phone
# Windows Server
# Windows Sharepoint Services
# Windows Vista
# Windows XP
# WindSim
# Windward Software Windward System Five
# Windward Technologies GRG2
# Wine
# Wine &amp; Spirits Industry
# Wine Cellars
# Wine Lists
# Wine Tasting
# Wine Tours
# Winemaking
# WinEPIC
# Wineries
# WinEstimator WinEst
# WinForms
# Wing Chun
# WinGap
# WINGRIDDS
# WinMan SureSell
# WinMerge
# Winners Programs BirdStud
# Winners Programs Uni-Stud
# Winning Others Over
# WinOcular
# Winplot
# WinSpice
# Winstats
# Winsteps
# Wintac Pro
# WinTR-55
# Win-win
# WIP
# WIPO
# WIPS
# Wire Bonding
# Wire EDM
# Wire Framing
# Wire Line
# Wire Transfers
# Wire Wrapping
# WiredRed Software e/pop Basic
# Wireframes
# Wireless
# Wireless Access
# Wireless Broadband
# Wireless Communications Systems
# Wireless Mesh
# Wireless Networking
# Wireless Routers
# Wireless Security
# Wireless Sensor Networks
# Wireless USB
# Wireline
# Wireshark
# Wiring
# Wiring Diagrams
# Wisconsin Physicians Service Insurance CMS Secure Net Access Portal C-SNAP
# Wisdom Teeth
# WisdomForce DatabaseSync System
# Wise Installer
# Wise Packaging
# Wise Packaging Studio
# Wise Solutions Wise for Windows Installer
# WISP
# Wit
# Witchcraft
# Withdrawals
# Withholding
# Witness Location
# Witness Statements
# Wix
# Wizard
# WizSoft WizRule
# WizSoft WizWhy
# WLAN
# WLI
# WLL
# WLM
# WLR3
# WLST
# WMI
# WML
# WMOS
# WMS Implementations
# W-NOMINATE
# WOA
# Wolf
# Wolfel IMMI
# Wolfram
# Wolfram Research Derivatives
# Wolfram Research Mathematica
# Wolfram Research Mathematica Finance Essentials
# Wolfram Research Mathematica UnRisk Pricing Engine
# Woll2Woll InfoPower Studio
# Wolof
# Wolters Kluwer Financial Services ComplianceOne
# Wolters Kluwer Loislaw
# Wombat
# Women Leaders
# Women Owned Business
# Women&#39;s Health
# Women&#39;s Issues
# Women&#39;s Leadership
# Women&#39;s Ministry
# Women&#39;s Rights
# Women&#39;s Studies
# Wonderware
# Wonderware InTouch
# Wonderware InTouch HMI
# WooCommerce
# Wood
# Wood Carving
# Wood Graining
# Wood Shop
# Wood Turning
# Woodcut
# Woodland Management
# Woodward MotoTron Control Solutions MotoHawk
# Woodwind
# WoodWing
# Woodworking
# Wool
# Word
# Word Of Mouth
# Word Of Mouth Marketing
# Word Processing
# Word processing software
# Word recognition software
# WordPerfect
# WordPress
# Words+ E Z Keys for Windows
# WordWeb
# Work at Height
# Work Effectively
# Work in Unison with Staff
# Work inspection software
# Work Life Balance
# Work order management software
# Work order software
# Work Orders
# Work record software
# Work scheduling software
# Work Technology WorkTech Time
# Work time accounting software
# Work time tracking software
# Work Under Minimal Supervision
# Work Very Well with Others
# Workbrain Employee Scheduling
# Workbrain Time and Attendance
# Workcell simulation software
# Workers Compensation
# Workers&#39; Compensation Claims
# Workflow International Deskflow Enterprise
# Workflow software
# Workforce Development
# Workforce Management
# Workforce management software
# Workforce management system software
# Workforce Planning
# WorkForce Software EmpCenter Time and Attendance
# Working Abroad
# Working at Height
# Working Capital Management
# Working With Children
# Working With Clients
# WorkingArtist Systems WorkingArtist
# Workplace Giving
# Workplace Safety
# Workplace Violence
# Workscape HR Service Center
# Workscape Outsourced Employee Benefits Administration
# WorkSchedule.net
# Workshop Facilitation
# Workshops
# WorkTech MAXIMO
# World Cafe
# World Cinema
# WORLD Electronics Freedomware
# World Health Organization HealthMapper
# World History
# World Software Corporation Worldox
# World Vector Shoreline
# WorldAPP KeySurvey Suite
# WorldCat
# Worldspan Go!
# Worldwide Instructional Design System WIDS
# WorthMORE Software CaseWORTH
# WOTC
# Wound Care
# Wovens
# Wowza
# WPA
# WPC
# WPF
# WPF Development
# WPS
# WRAP
# Wrap Accounts
# Wraparound
# Wrapping
# Wraps
# WRDS
# Wrestling
# Wrestling Coaching
# WRF
# Wrike
# Write Brothers Dramatica
# Write-ups
# WriteWay Pro
# Writing
# Wrongful Death
# WRSHealth EMR
# WRT
# WSAD
# WSDL
# WSE
# WSGI
# WSH
# WSI Titan
# WSI TrueView Professional
# WSIB
# WSIB Claims Management
# WSPG
# WSRR
# WSS 2.0
# WSUS
# WTL
# WTO
# WTP
# WTT
# WTX
# WUFI
# Wufoo
# Wusik Wusikstation VSTi
# WWAN
# WWII
# Wwise
# Www
# wxWidgets
# Wyndgate Technologies ElDorado Donor
# Wyndgate Technologies SafeTrace
# Wyse
# WYSIWYG Layout Tools
# X.25 Protocol
# x86/x64 Assembler
# XaaS
# XACML
# XACT
# Xactimate
# Xactly
# Xactly Compel
# Xactly Incent
# Xactware Xactimate
# Xajax
# Xalan
# Xamarin
# XAML
# XAMPP
# Xara
# Xara Designer Pro X
# Xara X
# Xara Xtreme
# XATA
# XATA XATANET
# XAUI
# xBase
# Xbox
# Xbox 360
# Xbox One
# XBR
# XBRL
# XCAL
# Xcalibur
# XCAP
# Xcart
# xCAT
# Xcircuit
# Xcode
# XCOM
# xCP
# XDCAM
# Xdebug
# XDoclet
# Xen
# XenClient
# Xenix
# Xenu
# Xerceo Learn
# Xerces
# Xerces2 Java Parser
# Xeriscaping
# Xero
# Xerox DocuShare
# Xerox FreeFlow Print Server
# Xerox Government systems FIREHOUSE Software
# Xerox Printers
# Xerox ProfitQuick
# Xetra
# Xfig
# XFire
# XFOIL
# XForms
# XFP
# XFS
# xgboost
# XGobi
# XHTML
# XIFIN
# Xilinx
# Xilinx Integrated Software Environment ISE
# Xilinx ISE
# Xilinx ISE Foundation
# Xilinx ModelSim
# Xilinx Synthesis Technology XST
# Xilinx TMRTool
# Xinet
# Xing
# Xitona Software Voice Composer
# XLISP-STAT
# XLMiner
# XLSTAT
# XMetal
# XMetaL Author
# XMind
# XML
# XML authoring software
# XML Databases
# XML Gateway
# XML Path Language XPATH
# XML Programming
# XML Publisher
# XML Schema
# XML Schema Design
# XML Scripting
# XML Sitemaps
# XML Spy
# XML Standards
# XML User Interface XUI
# XMLBeans
# XMLHTTP
# XML-RPC
# XMPie
# XMPP
# XNA
# XNAT
# XOG
# Xojo
# Xoops
# XP Software XPSWMM
# XPAC
# XPages
# XPath
# xPC Target
# XPDL
# Xpediter
# Xperts iep.online
# Xplan
# XPlanner
# xPON
# Xpress
# xPression
# XPS
# XQuery
# X-ray
# X-ray Absorption Spectroscopy
# X-ray crystallography
# X-ray Diffraction Analysis
# X-ray diffractometry
# X-ray Microanalysis
# X-ray Spectroscopy
# XRF
# XRR
# XRY
# Xsan
# XSD
# xSeries
# Xserve
# XSI
# Xsigo
# XSL
# XSL-FO
# XSLT
# XSS
# XStream
# XT Software energyXT
# XTRAC
# XTRACT
# XUL
# xUnit
# XV
# X-Ways
# XY Soft Sheet Cutting Suite
# Xyleme Learning Content Management System LCMS
# Xytech
# Xythos Enterprise Document Management Suite
# Yacc
# Yacht Charters
# Yacht Clubs
# Yacht Deliveries
# Yacht Racing
# Yachting
# Yahoo Search
# Yahoo Search Marketing
# Yahoo Site Explorer
# Yahoo! Email
# Yahoo! Store Design
# Yamaha Digital Consoles
# Yamaha M7CL
# Yamaha PM5D
# YAML
# Yammer
# Yantra
# Yard Management
# Yard Signs
# Yard Work
# Yard Work / Removal
# Yardi
# Yardi Enterprise
# Yardi Property Management
# Yardi Systems Yardi Enterprise
# Yardi Systems Yardi Voyager Commercial
# Yardi Systems Yardi Voyager Condo, Co-op, and HOA
# Yardi Systems Yardi Voyager Residential
# Yardi Voyager
# Yarn
# Yaskawa
# Year End Accounts
# Yearbook
# Year-end Close
# Yeast
# Yeast two-hybrid
# Yellow Belt
# Yellow Book
# Yellow Pages
# Yelp
# Yet another scientific artificial reality application YASARA software
# Yiddish
# Yield
# Yield Management
# Yield management systems
# Yields
# yieldWerx
# Yii
# Yin Yoga
# YMS
# Yocum & McKee The Complete AAP
# Yodeling
# Yoga
# Yoga Instruction
# Yoga Nidra
# Yogurt
# Yokogawa FAST/TOOLS
# Yoruba
# Yost Engineering ABN Assistant
# Yost Engineering ClaimScrub
# Yost Engineering CodeSearch Pro
# Yost Engineering EpiCoder
# Yost Engineering EPStaffCheck
# Young Adult Literature
# Young Adult Services
# Young Adults
# Young Mania Rating Scale
# Young People
# YourKit Java Profiler
# Youth At Risk
# Youth Culture
# Youth Development
# Youth Empowerment
# Youth Engagement
# Youth Entrepreneurship
# Youth Justice
# Youth Leadership
# Youth Leadership Training
# Youth Marketing
# Youth Mentoring
# Youth Ministry
# Youth Outreach
# Youth Programs
# Youth Work
# YouTube
# YouTube API
# YSlow
# YUI
# YUM
# Zabbix
# Zachman
# Zainet
# Zbrush
# Zebra
# Zebrafish
# Zedo
# ZedX AgFleet
# Zeiss
# Zemax
# ZEMAX Optical Design Program
# Zen
# Zen Cart
# Zen Shiatsu
# ZenCart
# Zend
# Zend Certified Engineer
# Zend Framework
# Zend Server
# Zend Studio
# Zendesk
# Zenoss
# Zenworks
# Zeolites
# Zephyr
# Zephyr EXTRA! Terminal Emulation
# Zephyr Style Advisor
# Zero Balancing
# Zero Defects
# Zero Waste
# Zero-based Budgeting
# ZeroMQ
# Zeta Potential
# Zeus
# ZFS
# Ziatek RoofDraw
# ZigBee
# Ziiva Prosperity LMS
# Zillow
# Zimbra
# Zinc
# Zines
# zkipster
# zLinux
# Zmanda Amanda
# Zmap
# Zocalo
# Zoho
# Zoho Projects
# Zoho WebNMS Cell Tower Manager
# Zoller
# Zombies
# Zone Alarm
# Zone modeling software
# Zoning
# Zoo
# Zooarchaeology
# Zoology
# Zoom
# Zoomerang
# ZoomInfo
# ZoomText
# ZoomWare Screen Magnifier
# Zope
# Zotero
# ZPL
# zSeries
# Zsh
# z-Tree
# Zuken
# Zuken CADSTAR
# Zuken E3.schematic
# Zultys
# Zumba
# Zumba Instruction
# Zung Depression Rating Scale
# Zuora
# Z-Wave
# Zylab ZyImage
# Zymography
# ZynAddSubFX
# Zynx
# ZYTO LSA Pro
# Zyxel

# %% [markdown]
# #### Extracted technical skills on the basis of presence of of raw skill in preprocessed technical skillset

# %%
def intersection(raw_list, tech_list):
    out = [value for value in raw_list if value in tech_list]
    out = pd.DataFrame(out)
    return out

technical_skills = intersection(raw_list, tech_list).value_counts().index.values
# print(intersection(raw_list, tech_list).value_counts().index.values)
# print(len(intersection(raw_list, tech_list).value_counts().index.values))
print(technical_skills)
print(len(technical_skills))
# Out:
# [('ACLS',) ('PostgreSQL',) ('Perl',) ('Phantom',) ('PhantomJS',)
#  ('Photoshop',) ('Pipelines',) ('Pivot',) ('PoE',) ('PostGIS',)
#  ('Powershell',) ('Perforce',) ('Printers',) ('Problem Solving',)
#  ('Puppet',) ('Pygame',) ('Python',) ('QNX',) ('QlikView',)
#  ('Quality Assurance',) ('Performance Tuning',) ('Pentaho',) ('RBAC',)
#  ('PHPUnit',) ('PCI DSS',) ('PCIe',) ('PCL',) ('PCM',) ('PDCP',) ('PDF',)
#  ('PFMEA',) ('PHP',) ('PID',) ('Penetration Testing',) ('PKI',) ('PMC',)
#  ('POS',) ('PPC',) ('PTP',) ('PWA',) ('PaaS',) ('Paychex',) ('RAFT',)
#  ('RCA',) ('SCSS',) ('SAS',) ('Ruby',) ('SAML',) ('SAP',)
#  ('SAP Analytics Cloud',) ('SAP BW',) ('SAP Business Objects',)
#  ('SAP HANA',) ('SAP Lumira',) ('SAS Base',) ('Riak',)
#  ('SAS Enterprise Guide',) ('SAS JMP',) ('SAS Programming',) ('SASS',)
#  ('SBT',) ('SCA',) ('SCADA',) ('SCOM',) ('Robot Framework',)
#  ('Responsive Web Design',) ('RDBMS',) ('RTOS',) ('RMAN',) ('RMI',)
#  ('RMS',) ('RPC',) ('RRC',) ('RSpec',) ('RTB',) ('RTEMS',) ('RTSP',)
#  ('Reinforcement Learning',) ('RabbitMQ',) ('Radius',) ('React.js',)
#  ('Readiness',) ('Redis',) ('Redmine',) ('Redshift',) ('Refactoring',)
#  ('PCA',) ('Overtime',) ('Orchestration',) ('Mocha',)
#  ('Microsoft .NET Framework',) ('Microsoft Active Directory',)
#  ('Microsoft Azure',) ('Microsoft Azure Networking',)
#  ('Microsoft Certified Professional',) ('Microsoft Excel',)
#  ('Microsoft SQL Server',) ('Middleware',) ('Mockito',) ('MicroStrategy',)
#  ('Modbus',) ('Modeling',) ('MongoDB',) ('Multimeter',)
#  ('Multithreading',) ('MyBatis',) ('MySQL',) ('NAS',)
#  ('Microcontrollers',) ('Messaging',) ('Oracle WebLogic',) ('Mailchimp',)
#  ('MQTT',) ('MSMQ',) ('MTTR',) ('MVC',) ('MVS',) ('MVVM',) ('Mac OS',)
#  ('Magento',) ('Mainframe',) ('Message Queue',) ('MapReduce',)
#  ('MariaDB',) ('Matlab',) ('Maven',) ('Maya',)
#  ('Medication Therapy Management',) ('Memcached',) ('Mentoring',) ('NFS',)
#  ('NIO',) ('NIST',) ('Octopus',) ('ODS',) ('OOAD',) ('OOP',) ('ORC',)
#  ('ORM',) ('OSI Model',) ('OTA',) ('Object Oriented Design',)
#  ('Octopus Deploy',) ('NLP',) ('OneStream',) ('Oozie',) ('OpenGL',)
#  ('OpenSSL',) ('OpenShift',) ('OpenStack',) ('Optimization',) ('Oracle',)
#  ('OCR',) ('OBC',) ('OAuth',) ('OAM',) ('NLTK',) ('NMS',) ('NOC',)
#  ('NTP',) ('NUnit',) ('Nagios',) ('Neo4j',) ('NetApp',) ('NetSuite',)
#  ('Networking',) ('Nexus',) ('Nginx',) ('NoSQL',) ('Normalization',)
#  ('Novell',) ('NuGet',) ('NumPy',) ('SCPI',) ('SCTP',) ('ADB',) ('VSS',)
#  ('VBA',) ('VHDL',) ('VLAN',) ('VMware',) ('VMware ESX',)
#  ('VMware vSphere',) ('VPN',) ('VPP',) ('VSTS',) ('Unstructured Data',)
#  ('Validation',) ('Varnish',) ('Vault',) ('Veeam',) ('Video Compression',)
#  ('Vim',) ('VirtualBox',) ('Virtualization',) ('VB.NET',)
#  ('Unreal Engine',) ('Visual SVN',) ('Twilio',) ('Test Automation',)
#  ('Test Scenarios',) ('TestNG',) ('Three.js',) ('Ticketing',) ('Tomcat',)
#  ('Triage',) ('Troubleshooting',) ('Typescript',) ('Underscore.js',)
#  ('UART',) ('UCS',) ('UDP',) ('UDS',) ('UML',) ('UNIX',) ('USB',)
#  ('Ubuntu',) ('Visio',) ('Visualization',) ('SDK',) ('Zoho',) ('Xen',)
#  ('Xero',) ('YAML',) ('Yarn',) ('Zabbix',) ('Zend',) ('Zendesk',)
#  ('ZigBee',) ('Zoom',) ('Xamarin',) ('Zuora',) ('eCTD',) ('eCommerce',)
#  ('iFix',) ('iTunes',) ('jQuery',) ('node.js',) ('pfSense',) ('Xcode',)
#  ('XSS',) ('VxWorks',) ('WebSphere',) ('Vyatta',) ('WCAG',) ('WCF',)
#  ('WLAN',) ('WPA',) ('WPF',) ('Waterfall',) ('WebLogic',) ('WiFi',)
#  ('XSLT',) ('WinForms',) ('Wireline',) ('WooCommerce',) ('WordPress',)
#  ('XAML',) ('XHTML',) ('XML',) ('XSD',) ('Teradata',) ('Templates',)
#  ('Telecommunications',) ('Salesforce',) ('SSL',) ('SSO',) ('SSRS',)
#  ('STS',) ('SVG',) ('SVM',) ('SaaS',) ('Sage',)
#  ('Salesforce Marketing Cloud',) ('SSH',) ('Salesforce.com',) ('Scala',)
#  ('Scanners',) ('Scripting',) ('Scrum',) ('Selenium',) ('Servlets',)
#  ('Sharepoint',) ('SSIS',) ('SQLite',) ('Teamwork',) ('SIL',)
#  ('SDK development',) ('SDL',) ('SDLC',) ('SDTM',) ('SECS/GEM',) ('SFDC',)
#  ('SFTP',) ('SIEM',) ('SLA',) ('SQL',) ('SLI',) ('SMB',) ('SME',)
#  ('SMI-S',) ('SMTP',) ('SNMP',) ('SOA',) ('SPI',) ('Shell Scripting',)
#  ('Shopify',) ('Simulink',) ('TCP',) ('Storyboard',) ('Struts',)
#  ('Subversion',) ('SuccessFactors',) ('Sybase',) ('Symfony',)
#  ('Symphony',) ('TAM',) ('TCP/IP',) ('Sinatra',) ('TDM',) ('TFS',)
#  ('TOGAF',) ('TPM',) ('TPT',) ('TTD',) ('Tableau',) ('Talend',)
#  ('Stored Procedures',) ('Stakeholder Engagement',) ('Spring MVC',)
#  ('Spring Batch',) ('Singleton',) ('Sitecore',) ('Six Sigma',) ('Sizing',)
#  ('Skype',) ('Slack',) ('Smartphones',) ('Snort',) ('Snowflake',) ('SoC',)
#  ('SoapUI',) ('Software Craftsmanship',) ('SolarWinds',) ('Sonar',)
#  ('Sortation',) ('Spark',) ('Splunk',) ('MPLS',) ('MISRA',) ('MIS',)
#  ('CSS',) ('CPD',) ('CPE',) ('CRB',) ('CRFs',) ('CRM',) ('CSAT',) ('CSE',)
#  ('CSRs',) ('CSSLP',) ('COBIT',) ('CSV',) ('CTT',) ('CUDA',) ('CVS',)
#  ('CakePHP',) ('Cassandra',) ('CentOS',) ('Chrome',) ('CPA',) ('CMS',)
#  ('Citect',) ('CDISC',) ('CAD',) ('CANoe',) ('CAPA',) ('CCDA',) ('CCNA',)
#  ('CCNP',) ('CCTV',) ('CDC',) ('CDP',) ('CMIS',) ('CDS',) ('CEH',)
#  ('CFR',) ('CISM',) ('CISSP',) ('CLI',) ('CLR',) ('CMDB',) ('Cisco',)
#  ('Citrix',) ('MFC',) ('DOM',) ('DFSS',) ('DHCP',) ('DHTML',)
#  ('DIgSILENT PowerFactory',) ('DLP',) ('DMP',) ('DNP3',) ('DNS',) ('DRM',)
#  ('DFMA',) ('DSL',) ('Dashboard',) ('Data Modeling',)
#  ('Data Visualization',) ('Data Warehousing',) ('Databases',)
#  ('Debuggers',) ('Delphi',) ('DFS',) ('DDS',) ('Clojure',) ('Core Java',)
#  ('Cloud Computing',) ('Cocoa Touch',) ('Cocos2d',) ('Coda',) ('Coding',)
#  ('Cognos',) ('Confluence',) ('Consul',) ('Crucible',) ('DDL',)
#  ('CruiseControl',) ('Cryptography',) ('Cubes',) ('Cucumber',)
#  ('Cypress',) ('DAX',) ('DBT',) ('DDD',) ('Builders',) ('Bower',)
#  ('Bootstrap',) ('Aggregation',) ('AWR',) ('AWS Redshift',)
#  ('Active Directory',) ('ActiveMQ',) ('Actuarial Science',) ('Adherence',)
#  ('Adobe Creative Suite',) ('Adobe Photoshop',) ('Agile Development',)
#  ('ATG',) ('Agile Methodologies',) ('Agility',) ('Algorithm Design',)
#  ('Algorithms',) ('Allscripts',) ('Alteryx',) ('Altium',)
#  ('Altium Designer',) ('ATP',) ('ATDD',) ('Bitbucket',) ('ALSA',)
#  ('ADDM',) ('ADF',) ('ADFS',) ('ADO',) ('ADO.NET',) ('AFS',) ('AJAX',)
#  ('ALM',) ('AMQP',) ('ATA',) ('APAC',) ('APIs',) ('ARP',) ('ASIC',)
#  ('ASP',) ('ASP.NET',) ('ASP.NET MVC',) ('ASRS',) ('Amazon Kinesis',)
#  ('Amazon Lambda',) ('Amazon SQS',) ('BODS',) ('Aura',) ('AutoCAD',)
#  ('Automation',) ('Avalanche',) ('Avro',) ('Azure',) ('BDD',) ('BGP',)
#  ('BSC',) ('Analytical Skills',) ('Backhaul',) ('Bamboo',) ('Basel II',)
#  ('Bash',) ('Bids',) ('Big Data Analytics',) ('Bind',) ('Biostatistics',)
#  ('Athena',) ('Assurance',) ('Assembler',) ('Asana',) ('Analytics',)
#  ('Android SDK',) ('Angular.js',) ('AngularJS',) ('Announcements',)
#  ('Ant',) ('Apache',) ('Apache Ant',) ('Apache Commons',)
#  ('Apache Kafka',) ('Apache Maven',) ('Apache Oozie',) ('Apache Spark',)
#  ('Apache Sqoop',) ('Apache Tomcat',) ('Apollo',) ('Ariba',)
#  ('Dependency Injection',) ('DevOps',) ('Django',) ('Internet Explorer',)
#  ('ISO',) ('ISS',) ('ISTQB',) ('ITIL',) ('IaaS',) ('Iconics',)
#  ('Illustrator',) ('Instrumentation',) ('Interpersonal Skills',) ('IPv6',)
#  ('Interpreter',) ('IoC',) ('Ionic Framework',) ('J2EE',) ('JAAS',)
#  ('JAXB',) ('JCR',) ('JDBC',) ('ISA',) ('IPv4',) ('HTML5',) ('Hyperion',)
#  ('Haskell',) ('Heroku',) ('Hibernate',) ('Hindi',) ('Hive',) ('HubSpot',)
#  ('Hybris',) ('Hyper-V',) ('Hypervisor',) ('IPTV',) ('IAM',) ('IDE',)
#  ('IDP',) ('IFRS',) ('IIS',) ('IPC',) ('IPM',) ('IPSec',) ('JIRA',)
#  ('JMS',) ('JMX',) ('Lauterbach',) ('Kondor+',) ('Kotlin',) ('LDAP',)
#  ('LIN',) ('LINQ',) ('LabVIEW',) ('Laptops',) ('Laravel',) ('Leisure',)
#  ('JMeter',) ('Linux',) ('Linux Kernel',) ('Listings',)
#  ('Loan Origination',) ('Logging',) ('Logistics',) ('Lua',) ('MDB',)
#  ('Kofax',) ('Kerberos',) ('Katalon',) ('Karma',) ('JNDI',) ('JPA',)
#  ('JSF',) ('JSON',) ('JSP',) ('JSTL',) ('JScript',) ('JTA',) ('JUnit',)
#  ('JVM',) ('Java Enterprise Edition',) ('Javascript',) ('Jenkins',)
#  ('Jitterbit',) ('KMS',) ('KVM',) ('Kanban',) ('Hadoop',) ('HTML',)
#  ('DoD',) ('Embedded Software',) ('Eclipse',) ('Eclipse IDE',)
#  ('Elasticsearch',) ('Eldo',) ('Elixir',) ('Eloqua',) ('Embedded C',)
#  ('Embedded Linux',) ('Ember.js',) ('ETFs',) ('Enablement',)
#  ('Enterprise Mobility',) ('Entity Framework',) ('Erlang',) ('Ethereum',)
#  ('Ethernet',) ('Excel',) ('Ext JS',) ('ETL',) ('ETAP',) ('HSM',)
#  ('ECMAScript',) ('Docker',) ('Doctrine',) ('Documentation',) ('Dojo',)
#  ('Drools',) ('Drupal',) ('EAC',) ('EAP',) ('ECS',) ('ESXi',) ('EDA',)
#  ('EDR',) ('EJB',) ('ELA',) ('EMC',) ('EMEA',) ('EMR',) ('ERP',) ('FIM',)
#  ('FMEA',) ('FPGA',) ('Google Analytics',) ('Gameplay Programming',)
#  ('Ganglia',) ('Generators',) ('Geography',) ('Git',) ('GitHub',)
#  ('Glue',) ('Golang',) ('Grails',) ('FTP',) ('Groovy',) ('Grunt',)
#  ('Gstreamer',) ('Guidewire PolicyCenter',) ('Gulp',) ('HBase',)
#  ('HIPAA',) ('HP Fortify',) ('GWT',) ('GUI',) ('GSD',) ('GPU',)
#  ('Facilitation',) ('Fedora',) ('Fibre',) ('Fiddler',) ('FileNet',)
#  ('Firefox',) ('Firewalls',) ('Flume',) ('Force.com',) ('Forecasting',)
#  ('GAMP',) ('GCC',) ('GCP',) ('GCS',) ('GNU tools',) ('GPFS',) ('GPRS',)
#  ('xUnit',)]
# 698

# %% [markdown]
# ### Thus I succeeded in extracting 698 technical/hard skills from the dataset
